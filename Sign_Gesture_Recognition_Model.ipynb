# %% [markdown]
# mount google drive

# %%
from google.colab import drive

# unmount first if already mounted
drive.flush_and_unmount()

# mount the drive again
drive.mount('/content/drive')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %% [markdown]
# necessary imports

# %%
# !pip install mediapipe
# !pip uninstall -y numpy
# !pip install numpy==2.0.2
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Collecting numpy<2 (from mediapipe)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.25.6)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 63.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 106.8 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: numpy, sounddevice, mediapipe
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed mediapipe-0.10.21 numpy-1.26.4 sounddevice-0.5.1
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.6 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 100.9 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2

# %%
import os
import shutil
import re
import random
import numpy as np
import cv2
import sys
import mediapipe as mp
import imageio
import h5py
import logging
import multiprocessing

from PIL import Image, ImageEnhance, ImageSequence
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.mixed_precision import LossScaleOptimizer, set_global_policy
from tensorflow.keras.models import load_model
from sklearn.utils.class_weight import compute_class_weight

import pickle
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# data folders

# %%
input_folder = "/content/drive/MyDrive/Colab Notebooks/Data/chosen_signs/"
output_folder = "/content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/"

# create output directory if it does not exist
os.makedirs(output_folder, exist_ok = True)

# %% [markdown]
# # Augment Data

# %% [markdown]
# augment functions

# %%
def random_rotate(image):
  # slightly rotate the image randomly within +- 10 degrees
  angle = random.uniform(-10, 10)
  return image.rotate(angle, resample = Image.BICUBIC, fillcolor = (0, 0, 0, 0))

def random_brightness(image):
  # adjust brightness - slightly darken or brighten
  enhancer = ImageEnhance.Brightness(image)
  factor = random.uniform(0.7, 1.3)
  return enhancer.enhance(factor)

def random_contrast(image):
  # adjust contrast slightly
  enhancer = ImageEnhance.Contrast(image)
  factor = random.uniform(0.7, 1.3)
  return enhancer.enhance(factor)

def random_translate(image):
  # translate image slightly - shift max 10 pixels along the x and/or y axis
  max_shift = 10
  dx, dy = random.randint(-max_shift, max_shift), random.randint(-max_shift, max_shift)
  return image.transform(image.size, Image.AFFINE, (1, 0, dx, 0, 1, dy))

def random_sharpness(image):
  # adjust sharpness - make the image more or less sharp
  enhancer = ImageEnhance.Sharpness(image)
  factor = random.uniform(0.7, 1.3)
  return enhancer.enhance(factor)

def random_saturation(image):
  # adjust saturation - make the colors more or less vivid
  enhancer = ImageEnhance.Color(image)
  factor = random.uniform(0.7, 1.3)
  return enhancer.enhance(factor)

def random_noise(image):
  # add more noticeable random noise to the image - simulates poor lighting or noisy environments
  np_image = np.array(image)
  noise = np.random.normal(0, 10, np_image.shape)
  noisy_image = np_image + noise
  noisy_image = np.clip(noisy_image, 0, 255)
  return Image.fromarray(noisy_image.astype(np.uint8))

# %% [markdown]
# process data and apply augmentation functions

# %%
def extract_uppercase_name(filename):
  # extracts only the uppercase words at the front of the file - name of the gestures
  base_name = os.path.basename(filename).split('.')[0]  # get only the name without extenstion
  match = re.match(r'^([A-Z_]+)', base_name) # get uppercase words at the start
  return match.group(1) if match else base_name  # return words or not return whole name

# apply agumentation to gif and save - save original + 49 different variations of the data for training
def augment_gif(input_path, output_path, num_variations = 49, frame_skip = 5):
  gif = Image.open(input_path)
  frames = [frame.convert("RGBA").copy() for frame in ImageSequence.Iterator(gif)]  # extract frames and ensure in RGBA format (prevent glitches or distortions)

  class_filename = extract_uppercase_name(input_path)

  # save the original GIF
  original_save_path = os.path.join(output_path, f"{class_filename}_original.gif")
  frames[0].save(original_save_path, save_all = True, append_images = frames[1:], duration = gif.info['duration'], loop = 0)

  # generate augmented GIFs
  for i in range(num_variations):
      augmented_frames = []

      for idx, frame in enumerate(frames):
        frame = frame.convert("RGB")  # Convert to RGB format

        # apply augmentation only every 'frame_skip' frames
        if idx % frame_skip == 0:
          frame = random_rotate(frame)
          frame = random_brightness(frame)
          frame = random_contrast(frame)
          frame = random_translate(frame)
          frame = random_sharpness(frame)
          frame = random_saturation(frame)
          frame = random_noise(frame)

        augmented_frames.append(frame)

      # save augmented GIF
      save_path = os.path.join(output_path, f"{class_filename}_aug_{i}.gif")
      augmented_frames[0].save(save_path, save_all = True, append_images = augmented_frames[1:], duration = gif.info['duration'], loop = 0)

# function to process multiple GIFs in parallel
def process_gif(args):
    input_path, output_path, num_variations = args
    augment_gif(input_path, output_path, num_variations)

# function to process and update the tqdm progress bar
def process_gif_and_update_bar(input_path, output_path, num_variations, pbar):
    augment_gif(input_path, output_path, num_variations)
    pbar.update(1)  # update progress bar after processing each file

# function to augment gifs using threadpoolexecutor for parallel processing with tqdm
def augment_gifs_in_parallel(gif_files, output_path, num_variations = 29, num_workers = 4):
    with tqdm(total = len(gif_files), desc = "Processing GIFs", unit = "file") as pbar:
        # Use threadpoolexecutor instead of multiprocessing Pool
        with ThreadPoolExecutor(max_workers = num_workers) as executor:
            futures = []
            for input_path, file in gif_files:
                futures.append(executor.submit(process_gif_and_update_bar, input_path, output_path, num_variations, pbar))

            # wait for all futures to complete
            for future in as_completed(futures):
                future.result()  # get the result to handle exceptions if any

# %% [markdown]
# process all the gifs in the data folder

# %%
# get all gif files from input folder
gif_files = [(os.path.join(input_folder, file), file) for file in os.listdir(input_folder) if file.endswith(".gif")]

# run the augmentation process in parallel with tqdm progress bar
augment_gifs_in_parallel(gif_files, output_folder, num_variations = 49, num_workers = 4)

print("Augmentation completed! Augmented GIFs saved in:", output_folder)
# Out:
# Processing GIFs: 100%|██████████| 20/20 [43:50<00:00, 131.54s/file]
# Augmentation completed! Augmented GIFs saved in: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/

# %%
# get the total number of gifs from the augmented dataset (total number of data)
augmented_gifs = [file for file in os.listdir(output_folder) if file.endswith(".gif")]

print("\nTotal number of GIFs in the dataset:", len(augmented_gifs))
# Out:
# Total number of GIFs in the dataset: 1000

# %% [markdown]
# # Preprocess Data for Model

# %%
# initialize MediaPipe solutions
mp_pose = mp.solutions.pose
mp_hands = mp.solutions.hands

# initialize MediaPipe models
pose_model = mp_pose.Pose(static_image_mode = False, model_complexity = 2, min_detection_confidence = 0.5, min_tracking_confidence = 0.5)
hand_model = mp_hands.Hands(static_image_mode = False, min_detection_confidence = 0.5, min_tracking_confidence = 0.5)

class SGSL_Dataset(keras.utils.Sequence):
    def __init__(self, folder, batch_size = 32, max_frames = 50, preprocess_file = None):
        self.folder = folder
        self.batch_size = batch_size
        self.max_frames = max_frames
        self.preprocess_file = preprocess_file

        # gather all the GIF files from the folder
        self.gif_files = [os.path.join(folder, file) for file in os.listdir(folder) if file.endswith(".gif")]

        # extract labels from the file names and store them
        self.labels = self._extract_labels()

        # create sorted list of unique labels
        self.unique_labels = sorted(set(self.labels.values()))

        # maps each unique label to an integer index
        self.label_to_index = {label: i for i, label in enumerate(self.unique_labels)}

        # total number of unique labels (classes)
        self.num_classes = len(self.unique_labels)

        # if preprocess_file is provided, load the preprocessed data
        if self.preprocess_file:
            self.preprocessed_data = self.load_preprocessed_data()
        else:
            self.preprocessed_data = None  # no preprocessed data loaded

    def _extract_labels(self):
        # extract capitalized words from the GIF files names as the label
        labels = {}
        for file in self.gif_files:
            filename = os.path.basename(file).split('.')[0]
            # split the filename by underscores and get the capitalized words
            words = filename.split('_')
            # filter only the words that are all uppercase letters
            capitalized_words = [word for word in words if word.isupper()]
            # concatenate the capitalized words into a single label string
            label = " ".join(capitalized_words) if capitalized_words else "Unknown"
            labels[file] = label
        return labels

    def __len__(self):
        # returns the total number of batches
        return int(np.ceil(len(self.gif_files) / self.batch_size))

    def preprocess_gif(self, gif_path):
        # preprocess gif by extracting the frames, resizing them, and extracting hand landmarks
        print(f"Processing GIF: {gif_path}")
        landmarks = []  # to store the landmarks for each frame

        # extract frames from the gif using imageio
        gif_frames = imageio.mimread(gif_path, memtest=False)
        print(f"Total frames in GIF: {len(gif_frames)}")

        # read frames until max frames
        for idx, frame in enumerate(gif_frames[:self.max_frames]):
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)  # convert to bgr for opencv

            # process the frame for mediapipe pose, face, and hand landmark estimation
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            hand_results = hand_model.process(rgb_frame)  # hand landmarks
            pose_results = pose_model.process(rgb_frame)  # pose landmarks

            # initialize empty arrays (pose: 33 landmarks * 4 values, hands: 21 landmarks * 3 values each)
            pose = np.zeros(33 * 4)
            lh = np.zeros(21 * 3)
            rh = np.zeros(21 * 3)
            hand_rotation = np.zeros(2)  # left and right hand rotation
            hand_position = np.zeros(6)  # left and right hand relative to body

            # extract pose landmarks (mainly focusing on wrists)
            if pose_results.pose_landmarks:
                pose_data = np.array([[lm.x, lm.y, lm.z, lm.visibility] for lm in pose_results.pose_landmarks.landmark])
                pose = pose_data.flatten()

                # extract key body landmarks
                left_wrist = pose_data[15, :3]  # (x, y, z)
                right_wrist = pose_data[16, :3]  # (x, y, z)
                left_shoulder = pose_data[11, :3] # (x, y, z)
                right_shoulder = pose_data[12, :3] # (x, y, z)
                nose = pose_data[0, :3] # (x, y, z)

            else:
                left_wrist = np.zeros(3)
                right_wrist = np.zeros(3)
                left_shoulder = np.zeros(3)
                right_shoulder = np.zeros(3)
                nose = np.zeros(3)

            # extract hand landmarks
            if hand_results.multi_hand_landmarks and hand_results.multi_handedness:
                for i, hand_landmarks in enumerate(hand_results.multi_hand_landmarks):
                    label = hand_results.multi_handedness[i].classification[0].label

                    hand_data = np.array([[lm.x, lm.y, lm.z] for lm in hand_landmarks.landmark]).flatten()
                    if label == "Left":
                        lh = hand_data
                    elif label == "Right":
                        rh = hand_data

            # normalize hand positions relative to wrist landmarks
            if lh.any():
                lh = lh.reshape(21, 3)
                lh -= left_wrist

            if rh.any():
                rh = rh.reshape(21, 3)
                rh -= right_wrist

            # flatten back to (63,) to keep the original shape
            lh = lh.flatten()
            rh = rh.flatten()

            # calculate hand rotation based on wrist and index finger tip (palm facing direction)
            def calculate_hand_rotation(wrist, index_finger_tip):
                if np.any(wrist) and np.any(index_finger_tip):
                    hand_vector = index_finger_tip - wrist
                    z_axis = np.array([0, 0, 1])  # reference for forward direction
                    angle = np.arccos(np.dot(hand_vector, z_axis) / (np.linalg.norm(hand_vector) * np.linalg.norm(z_axis)))
                    return angle
                return 0

            if lh.any():
              hand_rotation[0] = calculate_hand_rotation(left_wrist, lh[8:11])  # index finger tip

            if rh.any():
              hand_rotation[1] = calculate_hand_rotation(right_wrist, rh[8:11])  # index finger tip

            # calculate hand position relative to body (chest & head) (in this case nose and shoulder)
            def calculate_hand_position(wrist, nose, shoulder):
                if np.any(wrist) and np.any(nose) and np.any(shoulder):
                    return np.array([
                        np.linalg.norm(wrist - nose),  # distance to nose
                        np.linalg.norm(wrist - shoulder)  # distance to shoulder
                    ])
                return np.zeros(2)

            hand_position[:2] = calculate_hand_position(left_wrist, nose, left_shoulder)
            hand_position[2:4] = calculate_hand_position(right_wrist, nose, right_shoulder)

            # two-hand sign alignment (relative wrist distance)
            if np.any(left_wrist) and np.any(right_wrist):
                hand_position[4:] = np.linalg.norm(left_wrist - right_wrist)  # Distance between wrists

            # combine pose (with wrist info), hand landmarks, rotation, and positioning
            frame_landmarks = np.concatenate((pose, lh, rh, hand_rotation, hand_position))
            landmarks.append(frame_landmarks)

        # ensure a consistent frame count by padding with zeros
        while len(landmarks) < self.max_frames:
            landmarks.append(np.zeros(33 * 4 + 21 * 3 * 2 + 2 + 6))  # pose + hands + rotation + positioning

        return np.array(landmarks)

    def preprocess_and_store(self, output_file):
      # open an HDF5 file for writing
      with h5py.File(output_file, 'w') as hf:
          for i, file in enumerate(self.gif_files):
              print(f"Processing GIF {i + 1}/{len(self.gif_files)}: {file}")
              landmarks = self.preprocess_gif(file)

              # create a group for each gif file
              group_name = os.path.basename(file)  # use the basename (e.g., SEA_aug_31.gif) as the group name
              group = hf.create_group(group_name)
              group.create_dataset('landmarks', data = landmarks)
              group.attrs['label'] = self.labels[file]  # store the label as an attribute

      print(f"Preprocessed data saved to {output_file}")

    def load_preprocessed_data(self):
      if os.path.exists(self.preprocess_file):
          preprocessed_data = {}
          with h5py.File(self.preprocess_file, 'r') as hf:
              for file in hf.keys():
                  group = hf[file]
                  preprocessed_data[file] = {
                      'landmarks': group['landmarks'][:],  # load landmarks
                      'label': group.attrs['label']  # load label
                  }
          return preprocessed_data
      else:
          raise FileNotFoundError(f"Preprocessed file {self.preprocess_file} not found!")

    def __getitem__(self, idx):
        # fetch batches of data for training
        batch_files = self.gif_files[idx * self.batch_size: (idx + 1) * self.batch_size]

        batch_landmarks = []

        # if preprocessed data is loaded, just fetch from it
        if self.preprocessed_data:
            for file in batch_files:
                data = self.preprocessed_data[file]
                batch_landmarks.append(data['landmarks'])
        else:
            # if not preprocessed, preprocess on the fly
            for file in batch_files:
                landmarks = self.preprocess_gif(file)
                batch_landmarks.append(landmarks)

        # convert to numpy arrays
        batch_landmarks = np.array(batch_landmarks)

        # extract the corresponding labels for each file in the batch
        batch_labels = [self.labels[file] for file in batch_files]

        # convert labels to their integer index values
        batch_labels = np.array([self.label_to_index[label] for label in batch_labels])

        return batch_landmarks, keras.utils.to_categorical(batch_labels, num_classes = self.num_classes)

    def print_dataset_info(self):
        print(f"Number of unique labels (classes): {self.num_classes}")
        print(f"Class distribution: {dict(zip(self.unique_labels, [list(self.labels.values()).count(label) for label in self.unique_labels]))}")

# %%
batch_size = 16
dataset = SGSL_Dataset(folder = output_folder, batch_size = batch_size)

# work on training dataset first to not have memory overload

# print dataset info
dataset.print_dataset_info()

# split the dataset into training and validation sets
indices = np.arange(len(dataset.gif_files))
train_indices, val_indices = train_test_split(indices, test_size = 0.2, random_state = 42)

# select gif file paths for training and validation sets
train_gif_files = [dataset.gif_files[i] for i in train_indices]

# create dictionaries mapping file paths to their corresponding labels
train_labels = {file: dataset.labels[file] for file in train_gif_files}

# create training dataset
train_dataset = SGSL_Dataset(folder = output_folder, batch_size = batch_size)
train_dataset.gif_files = train_gif_files
train_dataset.labels = train_labels
train_dataset.preprocess_and_store("/content/drive/MyDrive/Colab Notebooks/Data/train_data.h5")

# print dataset info
print("\nTraining Dataset Info:")
train_dataset.print_dataset_info()
# Out:
# Number of unique labels (classes): 20
# Class distribution: {'A': 50, 'B': 50, 'BOOK': 50, 'C': 50, 'D': 50, 'DRINK': 50, 'E': 50, 'EAT': 50, 'FOOD': 50, 'GO': 50, 'HELLO': 50, 'HOW ARE YOU': 50, 'I': 50, 'MAKE': 50, 'MONEY': 50, 'MY': 50, 'READ': 50, 'SCHOOL': 50, 'WATER': 50, 'YOU': 50}
# Processing GIF 1/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_6.gif
# Total frames in GIF: 149
# Processing GIF 2/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_34.gif
# Total frames in GIF: 47
# Processing GIF 3/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_36.gif
# Total frames in GIF: 42
# Processing GIF 4/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_40.gif
# Total frames in GIF: 42
# Processing GIF 5/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_4.gif
# Total frames in GIF: 42
# Processing GIF 6/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_original.gif
# Total frames in GIF: 85
# Processing GIF 7/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_37.gif
# Total frames in GIF: 164
# Processing GIF 8/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_28.gif
# Total frames in GIF: 74
# Processing GIF 9/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_7.gif
# Total frames in GIF: 16
# Processing GIF 10/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_45.gif
# Total frames in GIF: 89
# Processing GIF 11/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_17.gif
# Total frames in GIF: 135
# Processing GIF 12/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_31.gif
# Total frames in GIF: 165
# Processing GIF 13/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_31.gif
# Total frames in GIF: 74
# Processing GIF 14/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_original.gif
# Total frames in GIF: 42
# Processing GIF 15/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_12.gif
# Total frames in GIF: 137
# Processing GIF 16/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_37.gif
# Total frames in GIF: 17
# Processing GIF 17/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_23.gif
# Total frames in GIF: 42
# Processing GIF 18/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_46.gif
# Total frames in GIF: 164
# Processing GIF 19/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_45.gif
# Total frames in GIF: 42
# Processing GIF 20/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_18.gif
# Total frames in GIF: 89
# Processing GIF 21/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_21.gif
# Total frames in GIF: 17
# Processing GIF 22/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_30.gif
# Total frames in GIF: 137
# Processing GIF 23/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_24.gif
# Total frames in GIF: 149
# Processing GIF 24/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_10.gif
# Total frames in GIF: 164
# Processing GIF 25/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_4.gif
# Total frames in GIF: 149
# Processing GIF 26/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_original.gif
# Total frames in GIF: 165
# Processing GIF 27/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_28.gif
# Total frames in GIF: 16
# Processing GIF 28/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_46.gif
# Total frames in GIF: 17
# Processing GIF 29/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_44.gif
# Total frames in GIF: 42
# Processing GIF 30/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_36.gif
# Total frames in GIF: 33
# Processing GIF 31/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_43.gif
# Total frames in GIF: 17
# Processing GIF 32/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_43.gif
# Total frames in GIF: 149
# Processing GIF 33/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_2.gif
# Total frames in GIF: 16
# Processing GIF 34/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_45.gif
# Total frames in GIF: 33
# Processing GIF 35/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_7.gif
# Total frames in GIF: 149
# Processing GIF 36/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_6.gif
# Total frames in GIF: 165
# Processing GIF 37/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_2.gif
# Total frames in GIF: 31
# Processing GIF 38/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_43.gif
# Total frames in GIF: 121
# Processing GIF 39/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_8.gif
# Total frames in GIF: 41
# Processing GIF 40/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_40.gif
# Total frames in GIF: 31
# Processing GIF 41/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_original.gif
# Total frames in GIF: 164
# Processing GIF 42/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_17.gif
# Total frames in GIF: 41
# Processing GIF 43/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_31.gif
# Total frames in GIF: 33
# Processing GIF 44/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_39.gif
# Total frames in GIF: 89
# Processing GIF 45/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_22.gif
# Total frames in GIF: 17
# Processing GIF 46/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_24.gif
# Total frames in GIF: 164
# Processing GIF 47/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_30.gif
# Total frames in GIF: 19
# Processing GIF 48/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_18.gif
# Total frames in GIF: 149
# Processing GIF 49/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_18.gif
# Total frames in GIF: 165
# Processing GIF 50/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_27.gif
# Total frames in GIF: 31
# Processing GIF 51/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_22.gif
# Total frames in GIF: 135
# Processing GIF 52/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_40.gif
# Total frames in GIF: 149
# Processing GIF 53/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_11.gif
# Total frames in GIF: 121
# Processing GIF 54/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_38.gif
# Total frames in GIF: 42
# Processing GIF 55/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_17.gif
# Total frames in GIF: 19
# Processing GIF 56/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_33.gif
# Total frames in GIF: 17
# Processing GIF 57/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_32.gif
# Total frames in GIF: 33
# Processing GIF 58/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_27.gif
# Total frames in GIF: 74
# Processing GIF 59/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_30.gif
# Total frames in GIF: 74
# Processing GIF 60/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_0.gif
# Total frames in GIF: 149
# Processing GIF 61/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_24.gif
# Total frames in GIF: 85
# Processing GIF 62/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_20.gif
# Total frames in GIF: 33
# Processing GIF 63/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_21.gif
# Total frames in GIF: 165
# Processing GIF 64/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_47.gif
# Total frames in GIF: 41
# Processing GIF 65/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_45.gif
# Total frames in GIF: 31
# Processing GIF 66/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_22.gif
# Total frames in GIF: 42
# Processing GIF 67/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_41.gif
# Total frames in GIF: 85
# Processing GIF 68/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_7.gif
# Total frames in GIF: 42
# Processing GIF 69/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_9.gif
# Total frames in GIF: 42
# Processing GIF 70/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_8.gif
# Total frames in GIF: 47
# Processing GIF 71/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_5.gif
# Total frames in GIF: 16
# Processing GIF 72/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_26.gif
# Total frames in GIF: 165
# Processing GIF 73/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_41.gif
# Total frames in GIF: 42
# Processing GIF 74/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_12.gif
# Total frames in GIF: 31
# Processing GIF 75/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_19.gif
# Total frames in GIF: 16
# Processing GIF 76/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_1.gif
# Total frames in GIF: 149
# Processing GIF 77/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_12.gif
# Total frames in GIF: 41
# Processing GIF 78/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_47.gif
# Total frames in GIF: 47
# Processing GIF 79/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_19.gif
# Total frames in GIF: 149
# Processing GIF 80/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_35.gif
# Total frames in GIF: 89
# Processing GIF 81/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_43.gif
# Total frames in GIF: 47
# Processing GIF 82/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_0.gif
# Total frames in GIF: 74
# Processing GIF 83/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_6.gif
# Total frames in GIF: 31
# Processing GIF 84/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_11.gif
# Total frames in GIF: 17
# Processing GIF 85/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_43.gif
# Total frames in GIF: 165
# Processing GIF 86/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_45.gif
# Total frames in GIF: 42
# Processing GIF 87/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_3.gif
# Total frames in GIF: 42
# Processing GIF 88/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_38.gif
# Total frames in GIF: 19
# Processing GIF 89/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_32.gif
# Total frames in GIF: 41
# Processing GIF 90/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_43.gif
# Total frames in GIF: 74
# Processing GIF 91/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_41.gif
# Total frames in GIF: 74
# Processing GIF 92/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_38.gif
# Total frames in GIF: 89
# Processing GIF 93/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_28.gif
# Total frames in GIF: 33
# Processing GIF 94/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_44.gif
# Total frames in GIF: 19
# Processing GIF 95/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_5.gif
# Total frames in GIF: 47
# Processing GIF 96/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_46.gif
# Total frames in GIF: 19
# Processing GIF 97/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_36.gif
# Total frames in GIF: 74
# Processing GIF 98/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_16.gif
# Total frames in GIF: 47
# Processing GIF 99/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_0.gif
# Total frames in GIF: 165
# Processing GIF 100/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_38.gif
# Total frames in GIF: 149
# Processing GIF 101/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_35.gif
# Total frames in GIF: 47
# Processing GIF 102/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_18.gif
# Total frames in GIF: 42
# Processing GIF 103/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_25.gif
# Total frames in GIF: 47
# Processing GIF 104/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_27.gif
# Total frames in GIF: 19
# Processing GIF 105/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_9.gif
# Total frames in GIF: 121
# Processing GIF 106/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_14.gif
# Total frames in GIF: 149
# Processing GIF 107/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_1.gif
# Total frames in GIF: 47
# Processing GIF 108/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_41.gif
# Total frames in GIF: 16
# Processing GIF 109/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_34.gif
# Total frames in GIF: 121
# Processing GIF 110/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_43.gif
# Total frames in GIF: 33
# Processing GIF 111/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_48.gif
# Total frames in GIF: 16
# Processing GIF 112/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_22.gif
# Total frames in GIF: 16
# Processing GIF 113/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_43.gif
# Total frames in GIF: 16
# Processing GIF 114/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_41.gif
# Total frames in GIF: 42
# Processing GIF 115/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_16.gif
# Total frames in GIF: 33
# Processing GIF 116/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_17.gif
# Total frames in GIF: 33
# Processing GIF 117/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_1.gif
# Total frames in GIF: 31
# Processing GIF 118/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_44.gif
# Total frames in GIF: 31
# Processing GIF 119/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_28.gif
# Total frames in GIF: 137
# Processing GIF 120/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_22.gif
# Total frames in GIF: 41
# Processing GIF 121/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_17.gif
# Total frames in GIF: 165
# Processing GIF 122/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_33.gif
# Total frames in GIF: 164
# Processing GIF 123/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_19.gif
# Total frames in GIF: 17
# Processing GIF 124/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_4.gif
# Total frames in GIF: 89
# Processing GIF 125/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_36.gif
# Total frames in GIF: 85
# Processing GIF 126/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_29.gif
# Total frames in GIF: 47
# Processing GIF 127/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_2.gif
# Total frames in GIF: 47
# Processing GIF 128/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_3.gif
# Total frames in GIF: 16
# Processing GIF 129/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_20.gif
# Total frames in GIF: 85
# Processing GIF 130/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_36.gif
# Total frames in GIF: 135
# Processing GIF 131/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_17.gif
# Total frames in GIF: 89
# Processing GIF 132/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_34.gif
# Total frames in GIF: 31
# Processing GIF 133/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_22.gif
# Total frames in GIF: 85
# Processing GIF 134/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_6.gif
# Total frames in GIF: 137
# Processing GIF 135/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_original.gif
# Total frames in GIF: 135
# Processing GIF 136/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_28.gif
# Total frames in GIF: 17
# Processing GIF 137/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_23.gif
# Total frames in GIF: 137
# Processing GIF 138/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_36.gif
# Total frames in GIF: 47
# Processing GIF 139/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_25.gif
# Total frames in GIF: 42
# Processing GIF 140/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_35.gif
# Total frames in GIF: 33
# Processing GIF 141/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_0.gif
# Total frames in GIF: 16
# Processing GIF 142/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_6.gif
# Total frames in GIF: 33
# Processing GIF 143/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_47.gif
# Total frames in GIF: 135
# Processing GIF 144/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_34.gif
# Total frames in GIF: 135
# Processing GIF 145/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_15.gif
# Total frames in GIF: 19
# Processing GIF 146/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_26.gif
# Total frames in GIF: 19
# Processing GIF 147/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_39.gif
# Total frames in GIF: 42
# Processing GIF 148/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_43.gif
# Total frames in GIF: 42
# Processing GIF 149/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_24.gif
# Total frames in GIF: 135
# Processing GIF 150/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_38.gif
# Total frames in GIF: 74
# Processing GIF 151/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_44.gif
# Total frames in GIF: 149
# Processing GIF 152/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_47.gif
# Total frames in GIF: 165
# Processing GIF 153/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_22.gif
# Total frames in GIF: 74
# Processing GIF 154/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_18.gif
# Total frames in GIF: 135
# Processing GIF 155/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_12.gif
# Total frames in GIF: 17
# Processing GIF 156/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_29.gif
# Total frames in GIF: 165
# Processing GIF 157/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_31.gif
# Total frames in GIF: 31
# Processing GIF 158/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_15.gif
# Total frames in GIF: 42
# Processing GIF 159/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__original.gif
# Total frames in GIF: 47
# Processing GIF 160/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_32.gif
# Total frames in GIF: 164
# Processing GIF 161/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_15.gif
# Total frames in GIF: 47
# Processing GIF 162/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_46.gif
# Total frames in GIF: 33
# Processing GIF 163/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_33.gif
# Total frames in GIF: 149
# Processing GIF 164/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_20.gif
# Total frames in GIF: 42
# Processing GIF 165/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_45.gif
# Total frames in GIF: 135
# Processing GIF 166/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_5.gif
# Total frames in GIF: 165
# Processing GIF 167/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_42.gif
# Total frames in GIF: 137
# Processing GIF 168/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_9.gif
# Total frames in GIF: 41
# Processing GIF 169/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_12.gif
# Total frames in GIF: 19
# Processing GIF 170/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_13.gif
# Total frames in GIF: 42
# Processing GIF 171/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_38.gif
# Total frames in GIF: 164
# Processing GIF 172/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_19.gif
# Total frames in GIF: 85
# Processing GIF 173/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_38.gif
# Total frames in GIF: 135
# Processing GIF 174/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_39.gif
# Total frames in GIF: 164
# Processing GIF 175/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_0.gif
# Total frames in GIF: 164
# Processing GIF 176/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_3.gif
# Total frames in GIF: 121
# Processing GIF 177/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_25.gif
# Total frames in GIF: 42
# Processing GIF 178/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_17.gif
# Total frames in GIF: 149
# Processing GIF 179/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_47.gif
# Total frames in GIF: 42
# Processing GIF 180/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_45.gif
# Total frames in GIF: 85
# Processing GIF 181/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_36.gif
# Total frames in GIF: 41
# Processing GIF 182/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_32.gif
# Total frames in GIF: 165
# Processing GIF 183/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_48.gif
# Total frames in GIF: 137
# Processing GIF 184/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_4.gif
# Total frames in GIF: 31
# Processing GIF 185/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_44.gif
# Total frames in GIF: 165
# Processing GIF 186/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_8.gif
# Total frames in GIF: 149
# Processing GIF 187/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_28.gif
# Total frames in GIF: 47
# Processing GIF 188/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_32.gif
# Total frames in GIF: 149
# Processing GIF 189/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_39.gif
# Total frames in GIF: 149
# Processing GIF 190/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_35.gif
# Total frames in GIF: 85
# Processing GIF 191/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_4.gif
# Total frames in GIF: 41
# Processing GIF 192/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_10.gif
# Total frames in GIF: 135
# Processing GIF 193/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_21.gif
# Total frames in GIF: 137
# Processing GIF 194/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_26.gif
# Total frames in GIF: 149
# Processing GIF 195/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_48.gif
# Total frames in GIF: 33
# Processing GIF 196/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_13.gif
# Total frames in GIF: 149
# Processing GIF 197/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_12.gif
# Total frames in GIF: 47
# Processing GIF 198/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_35.gif
# Total frames in GIF: 19
# Processing GIF 199/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_37.gif
# Total frames in GIF: 137
# Processing GIF 200/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_46.gif
# Total frames in GIF: 149
# Processing GIF 201/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_4.gif
# Total frames in GIF: 165
# Processing GIF 202/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_23.gif
# Total frames in GIF: 42
# Processing GIF 203/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_26.gif
# Total frames in GIF: 16
# Processing GIF 204/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_35.gif
# Total frames in GIF: 42
# Processing GIF 205/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_4.gif
# Total frames in GIF: 42
# Processing GIF 206/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_17.gif
# Total frames in GIF: 85
# Processing GIF 207/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_32.gif
# Total frames in GIF: 74
# Processing GIF 208/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_original.gif
# Total frames in GIF: 42
# Processing GIF 209/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_13.gif
# ...
# Total frames in GIF: 17
# Processing GIF 733/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_43.gif
# Total frames in GIF: 137
# Processing GIF 734/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_37.gif
# Total frames in GIF: 41
# Processing GIF 735/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_2.gif
# Total frames in GIF: 149
# Processing GIF 736/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_27.gif
# Total frames in GIF: 17
# Processing GIF 737/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_0.gif
# Total frames in GIF: 85
# Processing GIF 738/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_9.gif
# Total frames in GIF: 47
# Processing GIF 739/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_0.gif
# Total frames in GIF: 17
# Processing GIF 740/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_37.gif
# Total frames in GIF: 165
# Processing GIF 741/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_6.gif
# Total frames in GIF: 42
# Processing GIF 742/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_41.gif
# Total frames in GIF: 149
# Processing GIF 743/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_8.gif
# Total frames in GIF: 85
# Processing GIF 744/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_16.gif
# Total frames in GIF: 121
# Processing GIF 745/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_24.gif
# Total frames in GIF: 33
# Processing GIF 746/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_29.gif
# Total frames in GIF: 149
# Processing GIF 747/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_11.gif
# Total frames in GIF: 16
# Processing GIF 748/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_1.gif
# Total frames in GIF: 42
# Processing GIF 749/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_38.gif
# Total frames in GIF: 41
# Processing GIF 750/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_37.gif
# Total frames in GIF: 16
# Processing GIF 751/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_18.gif
# Total frames in GIF: 74
# Processing GIF 752/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_42.gif
# Total frames in GIF: 33
# Processing GIF 753/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_14.gif
# Total frames in GIF: 89
# Processing GIF 754/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_7.gif
# Total frames in GIF: 41
# Processing GIF 755/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_45.gif
# Total frames in GIF: 137
# Processing GIF 756/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_18.gif
# Total frames in GIF: 85
# Processing GIF 757/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_original.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_original.gif
# Total frames in GIF: 16
# Processing GIF 758/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_30.gif
# Total frames in GIF: 42
# Processing GIF 759/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_30.gif
# Total frames in GIF: 33
# Processing GIF 760/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_12.gif
# Total frames in GIF: 165
# Processing GIF 761/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_22.gif
# Total frames in GIF: 33
# Processing GIF 762/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_34.gif
# Total frames in GIF: 16
# Processing GIF 763/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_15.gif
# Total frames in GIF: 42
# Processing GIF 764/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_26.gif
# Total frames in GIF: 89
# Processing GIF 765/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_13.gif
# Total frames in GIF: 31
# Processing GIF 766/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_4.gif
# Total frames in GIF: 149
# Processing GIF 767/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_26.gif
# Total frames in GIF: 17
# Processing GIF 768/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_42.gif
# Total frames in GIF: 19
# Processing GIF 769/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_36.gif
# Total frames in GIF: 164
# Processing GIF 770/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_24.gif
# Total frames in GIF: 31
# Processing GIF 771/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_40.gif
# Total frames in GIF: 121
# Processing GIF 772/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_41.gif
# Total frames in GIF: 165
# Processing GIF 773/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_2.gif
# Total frames in GIF: 33
# Processing GIF 774/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_43.gif
# Total frames in GIF: 85
# Processing GIF 775/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_23.gif
# Total frames in GIF: 19
# Processing GIF 776/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_6.gif
# Total frames in GIF: 16
# Processing GIF 777/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_42.gif
# Total frames in GIF: 31
# Processing GIF 778/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_41.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_41.gif
# Total frames in GIF: 137
# Processing GIF 779/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_48.gif
# Total frames in GIF: 165
# Processing GIF 780/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_22.gif
# Total frames in GIF: 42
# Processing GIF 781/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_29.gif
# Total frames in GIF: 164
# Processing GIF 782/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_10.gif
# Total frames in GIF: 89
# Processing GIF 783/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_24.gif
# Total frames in GIF: 42
# Processing GIF 784/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_24.gif
# Total frames in GIF: 149
# Processing GIF 785/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_6.gif
# Total frames in GIF: 19
# Processing GIF 786/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_19.gif
# Total frames in GIF: 164
# Processing GIF 787/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_21.gif
# Total frames in GIF: 47
# Processing GIF 788/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_36.gif
# Total frames in GIF: 17
# Processing GIF 789/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_24.gif
# Total frames in GIF: 41
# Processing GIF 790/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_45.gif
# Total frames in GIF: 19
# Processing GIF 791/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_33.gif
# Total frames in GIF: 135
# Processing GIF 792/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_2.gif
# Total frames in GIF: 42
# Processing GIF 793/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_4.gif
# Total frames in GIF: 135
# Processing GIF 794/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_38.gif
# Total frames in GIF: 42
# Processing GIF 795/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_15.gif
# Total frames in GIF: 165
# Processing GIF 796/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_23.gif
# Total frames in GIF: 165
# Processing GIF 797/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_22.gif
# Total frames in GIF: 31
# Processing GIF 798/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_17.gif
# Total frames in GIF: 42
# Processing GIF 799/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_32.gif
# Total frames in GIF: 19
# Processing GIF 800/800: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_22.gif
# Total frames in GIF: 165
# Preprocessed data saved to /content/drive/MyDrive/Colab Notebooks/Data/train_data.h5
#
# Training Dataset Info:
# Number of unique labels (classes): 20
# Class distribution: {'A': 43, 'B': 40, 'BOOK': 43, 'C': 44, 'D': 38, 'DRINK': 35, 'E': 39, 'EAT': 39, 'FOOD': 41, 'GO': 36, 'HELLO': 37, 'HOW ARE YOU': 38, 'I': 42, 'MAKE': 37, 'MONEY': 40, 'MY': 42, 'READ': 39, 'SCHOOL': 43, 'WATER': 43, 'YOU': 41}

# %%
# load the remaining validation set

batch_size = 16
dataset = SGSL_Dataset(folder = output_folder, batch_size = batch_size)

# load the training dataset to get successfully processed gifs
train_data_path = "/content/drive/MyDrive/Colab Notebooks/Data/train_data.h5"
if os.path.exists(train_data_path):
    with h5py.File(train_data_path, 'r') as train_data:
        processed_train_gifs = set(train_data.keys())  # set of training processed gifs
else:
    raise FileNotFoundError(f"Training dataset {train_data_path} not found!")

# get the remaining gifs for validation
remaining_gifs = [gif for gif in dataset.gif_files if gif.split('/')[-1] not in processed_train_gifs]

# update validation dataset only with remaining gifs
val_dataset = SGSL_Dataset(folder = output_folder, batch_size = batch_size)
val_dataset.gif_files = remaining_gifs
val_dataset.labels = {file: dataset.labels[file] for file in remaining_gifs}

# process and store the remaining validation dataset
val_data_path = "/content/drive/MyDrive/Colab Notebooks/Data/val_data.h5"
val_dataset.preprocess_and_store(val_data_path)

# print final validation dataset info
print("\nValidation Dataset Info (Processed Remaining GIFs):")
val_dataset.print_dataset_info()
# Out:
# Processing GIF 1/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_1.gif
# Total frames in GIF: 165
# Processing GIF 2/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_4.gif
# Total frames in GIF: 164
# Processing GIF 3/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_5.gif
# Total frames in GIF: 149
# Processing GIF 4/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_7.gif
# Total frames in GIF: 135
# Processing GIF 5/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_8.gif
# Total frames in GIF: 165
# Processing GIF 6/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_9.gif
# Total frames in GIF: 165
# Processing GIF 7/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_11.gif
# Total frames in GIF: 165
# Processing GIF 8/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_14.gif
# Total frames in GIF: 135
# Processing GIF 9/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_15.gif
# Total frames in GIF: 135
# Processing GIF 10/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_14.gif
# Total frames in GIF: 149
# Processing GIF 11/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_16.gif
# Total frames in GIF: 135
# Processing GIF 12/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_14.gif
# Total frames in GIF: 164
# Processing GIF 13/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_14.gif
# Total frames in GIF: 165
# Processing GIF 14/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_15.gif
# Total frames in GIF: 164
# Processing GIF 15/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_19.gif
# Total frames in GIF: 135
# Processing GIF 16/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_20.gif
# Total frames in GIF: 135
# Processing GIF 17/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_17.gif
# Total frames in GIF: 164
# Processing GIF 18/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_23.gif
# Total frames in GIF: 135
# Processing GIF 19/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_19.gif
# Total frames in GIF: 165
# Processing GIF 20/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_21.gif
# Total frames in GIF: 164
# Processing GIF 21/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_27.gif
# Total frames in GIF: 135
# Processing GIF 22/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_29.gif
# Total frames in GIF: 135
# Processing GIF 23/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_24.gif
# Total frames in GIF: 165
# Processing GIF 24/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_29.gif
# Total frames in GIF: 149
# Processing GIF 25/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_30.gif
# Total frames in GIF: 165
# Processing GIF 26/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_37.gif
# Total frames in GIF: 135
# Processing GIF 27/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_34.gif
# Total frames in GIF: 149
# Processing GIF 28/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_43.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_43.gif
# Total frames in GIF: 135
# Processing GIF 29/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/D_aug_46.gif
# Total frames in GIF: 135
# Processing GIF 30/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_39.gif
# Total frames in GIF: 165
# Processing GIF 31/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_3.gif
# Total frames in GIF: 41
# Processing GIF 32/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_13.gif
# Total frames in GIF: 41
# Processing GIF 33/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_46.gif
# Total frames in GIF: 149
# Processing GIF 34/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_20.gif
# Total frames in GIF: 41
# Processing GIF 35/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_47.gif
# Total frames in GIF: 149
# Processing GIF 36/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_21.gif
# Total frames in GIF: 41
# Processing GIF 37/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_23.gif
# Total frames in GIF: 41
# Processing GIF 38/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_25.gif
# Total frames in GIF: 41
# Processing GIF 39/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/A_aug_48.gif
# Total frames in GIF: 149
# Processing GIF 40/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_28.gif
# Total frames in GIF: 41
# Processing GIF 41/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_35.gif
# Total frames in GIF: 41
# Processing GIF 42/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_5.gif
# Total frames in GIF: 31
# Processing GIF 43/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_9.gif
# Total frames in GIF: 31
# Processing GIF 44/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_11.gif
# Total frames in GIF: 31
# Processing GIF 45/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/B_aug_46.gif
# Total frames in GIF: 165
# Processing GIF 46/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_15.gif
# Total frames in GIF: 31
# Processing GIF 47/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_44.gif
# Total frames in GIF: 41
# Processing GIF 48/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_17.gif
# Total frames in GIF: 31
# Processing GIF 49/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_45.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MONEY_aug_45.gif
# Total frames in GIF: 41
# Processing GIF 50/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_20.gif
# Total frames in GIF: 31
# Processing GIF 51/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_1.gif
# Total frames in GIF: 17
# Processing GIF 52/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_2.gif
# Total frames in GIF: 17
# Processing GIF 53/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_25.gif
# Total frames in GIF: 31
# Processing GIF 54/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_5.gif
# Total frames in GIF: 17
# Processing GIF 55/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_28.gif
# Total frames in GIF: 31
# Processing GIF 56/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_13.gif
# Total frames in GIF: 17
# Processing GIF 57/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_14.gif
# Total frames in GIF: 17
# Processing GIF 58/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_30.gif
# Total frames in GIF: 31
# Processing GIF 59/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/C_aug_48.gif
# Total frames in GIF: 164
# Processing GIF 60/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_17.gif
# Total frames in GIF: 17
# Processing GIF 61/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_33.gif
# Total frames in GIF: 31
# Processing GIF 62/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_23.gif
# Total frames in GIF: 17
# Processing GIF 63/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_24.gif
# Total frames in GIF: 17
# Processing GIF 64/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_25.gif
# Total frames in GIF: 17
# Processing GIF 65/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_35.gif
# Total frames in GIF: 31
# Processing GIF 66/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_29.gif
# Total frames in GIF: 17
# Processing GIF 67/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_30.gif
# Total frames in GIF: 17
# Processing GIF 68/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_37.gif
# Total frames in GIF: 31
# Processing GIF 69/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_35.gif
# Total frames in GIF: 17
# Processing GIF 70/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_39.gif
# Total frames in GIF: 31
# Processing GIF 71/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_38.gif
# Total frames in GIF: 17
# Processing GIF 72/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_1.gif
# Total frames in GIF: 42
# Processing GIF 73/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/GO_aug_47.gif
# Total frames in GIF: 17
# Processing GIF 74/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_4.gif
# Total frames in GIF: 47
# Processing GIF 75/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_46.gif
# Total frames in GIF: 31
# Processing GIF 76/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_2.gif
# Total frames in GIF: 19
# Processing GIF 77/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_3.gif
# Total frames in GIF: 19
# Processing GIF 78/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_5.gif
# Total frames in GIF: 42
# Processing GIF 79/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/DRINK_aug_48.gif
# Total frames in GIF: 31
# Processing GIF 80/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_0.gif
# Total frames in GIF: 33
# Processing GIF 81/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_1.gif
# Total frames in GIF: 33
# Processing GIF 82/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_21.gif
# Total frames in GIF: 19
# Processing GIF 83/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_13.gif
# Total frames in GIF: 47
# Processing GIF 84/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_28.gif
# Total frames in GIF: 19
# Processing GIF 85/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_16.gif
# Total frames in GIF: 42
# Processing GIF 86/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_31.gif
# Total frames in GIF: 19
# Processing GIF 87/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_17.gif
# Total frames in GIF: 42
# Processing GIF 88/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_34.gif
# Total frames in GIF: 19
# Processing GIF 89/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_19.gif
# Total frames in GIF: 42
# Processing GIF 90/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/SCHOOL__aug_39.gif
# Total frames in GIF: 19
# Processing GIF 91/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_22.gif
# Total frames in GIF: 42
# Processing GIF 92/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_23.gif
# Total frames in GIF: 33
# Processing GIF 93/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_4.gif
# Total frames in GIF: 16
# Processing GIF 94/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_28.gif
# Total frames in GIF: 42
# Processing GIF 95/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_27.gif
# Total frames in GIF: 47
# Processing GIF 96/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_9.gif
# Total frames in GIF: 16
# Processing GIF 97/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_15.gif
# Total frames in GIF: 16
# Processing GIF 98/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_18.gif
# Total frames in GIF: 16
# Processing GIF 99/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_33.gif
# Total frames in GIF: 33
# Processing GIF 100/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_34.gif
# Total frames in GIF: 42
# Processing GIF 101/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_34.gif
# Total frames in GIF: 33
# Processing GIF 102/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_21.gif
# Total frames in GIF: 16
# Processing GIF 103/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_33.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_33.gif
# Total frames in GIF: 47
# Processing GIF 104/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_24.gif
# Total frames in GIF: 16
# Processing GIF 105/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_37.gif
# Total frames in GIF: 42
# Processing GIF 106/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_27.gif
# Total frames in GIF: 16
# Processing GIF 107/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_38.gif
# Total frames in GIF: 42
# Processing GIF 108/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_30.gif
# Total frames in GIF: 16
# Processing GIF 109/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_40.gif
# Total frames in GIF: 33
# Processing GIF 110/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_38.gif
# Total frames in GIF: 47
# Processing GIF 111/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_40.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_40.gif
# Total frames in GIF: 47
# Processing GIF 112/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_42.gif
# Total frames in GIF: 16
# Processing GIF 113/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_44.gif
# Total frames in GIF: 16
# Processing GIF 114/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/WATER_aug_47.gif
# Total frames in GIF: 33
# Processing GIF 115/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/EAT_aug_46.gif
# Total frames in GIF: 16
# Processing GIF 116/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_46.gif
# Total frames in GIF: 42
# Processing GIF 117/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_47.gif
# Total frames in GIF: 42
# Processing GIF 118/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_48.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MAKE_aug_48.gif
# Total frames in GIF: 42
# Processing GIF 119/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/BOOK__aug_46.gif
# Total frames in GIF: 47
# Processing GIF 120/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_0.gif
# Total frames in GIF: 89
# Processing GIF 121/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_2.gif
# Total frames in GIF: 85
# Processing GIF 122/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_2.gif
# Total frames in GIF: 89
# Processing GIF 123/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_5.gif
# Total frames in GIF: 42
# Processing GIF 124/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_7.gif
# Total frames in GIF: 42
# Processing GIF 125/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_6.gif
# Total frames in GIF: 85
# Processing GIF 126/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_11.gif
# Total frames in GIF: 42
# Processing GIF 127/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_9.gif
# Total frames in GIF: 137
# Processing GIF 128/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_15.gif
# Total frames in GIF: 42
# Processing GIF 129/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_17.gif
# Total frames in GIF: 42
# Processing GIF 130/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_8.gif
# Total frames in GIF: 89
# Processing GIF 131/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_11.gif
# Total frames in GIF: 137
# Processing GIF 132/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_10.gif
# Total frames in GIF: 85
# Processing GIF 133/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_13.gif
# Total frames in GIF: 137
# Processing GIF 134/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_11.gif
# Total frames in GIF: 85
# Processing GIF 135/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_11.gif
# Total frames in GIF: 89
# Processing GIF 136/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_15.gif
# Total frames in GIF: 137
# Processing GIF 137/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_14.gif
# Total frames in GIF: 85
# Processing GIF 138/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_29.gif
# Total frames in GIF: 42
# Processing GIF 139/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_17.gif
# Total frames in GIF: 137
# Processing GIF 140/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_19.gif
# Total frames in GIF: 137
# Processing GIF 141/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_16.gif
# Total frames in GIF: 85
# Processing GIF 142/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_20.gif
# Total frames in GIF: 137
# Processing GIF 143/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_16.gif
# Total frames in GIF: 89
# Processing GIF 144/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_44.gif
# Total frames in GIF: 42
# Processing GIF 145/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_19.gif
# Total frames in GIF: 89
# Processing GIF 146/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_21.gif
# Total frames in GIF: 85
# Processing GIF 147/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/I__aug_47.gif
# Total frames in GIF: 42
# Processing GIF 148/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_31.gif
# Total frames in GIF: 137
# Processing GIF 149/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_2.gif
# Total frames in GIF: 121
# Processing GIF 150/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_32.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_32.gif
# Total frames in GIF: 137
# Processing GIF 151/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_4.gif
# Total frames in GIF: 121
# Processing GIF 152/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_36.gif
# Total frames in GIF: 137
# Processing GIF 153/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_6.gif
# Total frames in GIF: 121
# Processing GIF 154/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/READ_aug_39.gif
# Total frames in GIF: 137
# Processing GIF 155/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_31.gif
# Total frames in GIF: 89
# Processing GIF 156/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/MY_aug_36.gif
# Total frames in GIF: 89
# Processing GIF 157/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_1.gif
# Total frames in GIF: 74
# Processing GIF 158/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_42.gif
# Total frames in GIF: 85
# Processing GIF 159/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_4.gif
# Total frames in GIF: 74
# Processing GIF 160/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_15.gif
# Total frames in GIF: 121
# Processing GIF 161/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_46.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/YOU_aug_46.gif
# Total frames in GIF: 85
# Processing GIF 162/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_7.gif
# Total frames in GIF: 74
# Processing GIF 163/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_17.gif
# Total frames in GIF: 121
# Processing GIF 164/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_8.gif
# Total frames in GIF: 74
# Processing GIF 165/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_9.gif
# Total frames in GIF: 74
# Processing GIF 166/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_0.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_0.gif
# Total frames in GIF: 42
# Processing GIF 167/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_11.gif
# Total frames in GIF: 74
# Processing GIF 168/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_9.gif
# Total frames in GIF: 42
# Processing GIF 169/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_13.gif
# Total frames in GIF: 74
# Processing GIF 170/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_15.gif
# Total frames in GIF: 74
# Processing GIF 171/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_20.gif
# Total frames in GIF: 42
# Processing GIF 172/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_22.gif
# Total frames in GIF: 121
# Processing GIF 173/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_21.gif
# Total frames in GIF: 42
# Processing GIF 174/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_29.gif
# Total frames in GIF: 42
# Processing GIF 175/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_31.gif
# Total frames in GIF: 42
# Processing GIF 176/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_3.gif
# Total frames in GIF: 149
# Processing GIF 177/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_36.gif
# Total frames in GIF: 42
# Processing GIF 178/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_37.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_37.gif
# Total frames in GIF: 42
# Processing GIF 179/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_26.gif
# Total frames in GIF: 121
# Processing GIF 180/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_23.gif
# Total frames in GIF: 74
# Processing GIF 181/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/FOOD_aug_42.gif
# Total frames in GIF: 42
# Processing GIF 182/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_26.gif
# Total frames in GIF: 74
# Processing GIF 183/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_29.gif
# Total frames in GIF: 121
# Processing GIF 184/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_31.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_31.gif
# Total frames in GIF: 121
# Processing GIF 185/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_11.gif
# Total frames in GIF: 149
# Processing GIF 186/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_35.gif
# Total frames in GIF: 121
# Processing GIF 187/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_36.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_36.gif
# Total frames in GIF: 121
# Processing GIF 188/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_39.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_39.gif
# Total frames in GIF: 74
# Processing GIF 189/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HOW_ARE_YOU_aug_38.gif
# Total frames in GIF: 121
# Processing GIF 190/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_42.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_42.gif
# Total frames in GIF: 74
# Processing GIF 191/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/HELLO_aug_47.gif
# Total frames in GIF: 74
# Processing GIF 192/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_22.gif
# Total frames in GIF: 149
# Processing GIF 193/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_23.gif
# Total frames in GIF: 149
# Processing GIF 194/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_26.gif
# Total frames in GIF: 149
# Processing GIF 195/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_27.gif
# Total frames in GIF: 149
# Processing GIF 196/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_34.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_34.gif
# Total frames in GIF: 149
# Processing GIF 197/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_35.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_35.gif
# Total frames in GIF: 149
# Processing GIF 198/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_38.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_38.gif
# Total frames in GIF: 149
# Processing GIF 199/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_44.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_44.gif
# Total frames in GIF: 149
# Processing GIF 200/200: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_47.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/chosen_signs_augmented/E_aug_47.gif
# Total frames in GIF: 149
# Preprocessed data saved to /content/drive/MyDrive/Colab Notebooks/Data/val_data.h5
#
# Validation Dataset Info (Processed Remaining GIFs):
# Number of unique labels (classes): 20
# Class distribution: {'A': 7, 'B': 10, 'BOOK': 7, 'C': 6, 'D': 12, 'DRINK': 15, 'E': 11, 'EAT': 11, 'FOOD': 9, 'GO': 14, 'HELLO': 13, 'HOW ARE YOU': 12, 'I': 8, 'MAKE': 13, 'MONEY': 10, 'MY': 8, 'READ': 11, 'SCHOOL': 7, 'WATER': 7, 'YOU': 9}

# %% [markdown]
# # Training the model: 1D + Transformer Model

# %%
# enable mixed precision for faster training on GPUs
tf.keras.backend.clear_session()
tf.compat.v1.reset_default_graph()
set_global_policy("mixed_float16")

# transformer block
def transformer_block(x, num_heads = 4, ff_dim = 64, dropout_rate = 0.3):

    x_norm = layers.LayerNormalization(epsilon = 1e-6)(x)

    # scaled dot-product attention
    attention_output = layers.MultiHeadAttention(num_heads = num_heads, key_dim = ff_dim)(x_norm, x_norm)
    attention_output = layers.Dropout(dropout_rate)(attention_output)

    # residual connection
    x = layers.Add()([x, attention_output])

    # feed forward network (mlp)
    x_norm2 = layers.LayerNormalization(epsilon = 1e-6)(x)
    ff_output = layers.Dense(ff_dim * 2, activation = 'gelu')(x_norm2)
    ff_output = layers.Dense(ff_dim, activation = 'gelu')(ff_output)
    ff_output = layers.Dropout(dropout_rate)(ff_output)

    # residual connection
    x = layers.Add()([x, ff_output])

    return x

# 1d cnn + transformer model
def create_model(input_shape, num_classes):
    inputs = Input(shape = input_shape)

    # 1d convolutional layers
    x = layers.Conv1D(128, kernel_size = 3, strides = 1, padding = "same", activation = None)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv1D(256, kernel_size = 3, strides = 1, padding = "same", activation = None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Dropout(0.5)(x)

    # transformer block
    x = transformer_block(x, num_heads = 4, ff_dim = 256, dropout_rate = 0.3)
    x = transformer_block(x, num_heads = 4, ff_dim = 256, dropout_rate = 0.3)
    x = transformer_block(x, num_heads = 4, ff_dim = 256, dropout_rate = 0.3)
    x = layers.BatchNormalization()(x) # stabilize training after transformer block

    # flatten and dense layers
    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(128, activation = 'gelu', kernel_regularizer = tf.keras.regularizers.l2(5e-4))(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation = "softmax", dtype = "float32")(x)

    # optimizer with weight decay and gradient clipping
    optimizer = AdamW(learning_rate = 0.0001, weight_decay = 1e-4, clipnorm = 1.0)

    model = Model(inputs, outputs)
    model.compile(optimizer = optimizer, loss = tf.keras.losses.SparseCategoricalCrossentropy(), metrics = ['sparse_categorical_accuracy'])

    return model

# dataset loader
def load_dataset_efficient(h5_file, batch_size = 16, shuffle = True):
    # read all labels and create a mapping from class names to integer indices
    with h5py.File(h5_file, 'r') as hf:
        all_labels = [hf[k].attrs['label'].decode() if isinstance(hf[k].attrs['label'], bytes) else hf[k].attrs['label'] for k in hf.keys()]
        class_names = sorted(set(all_labels))  # get unique class names, sorted
        class_to_index = {name: idx for idx, name in enumerate(class_names)}  # mapping

    num_classes = len(class_names)  # total number of classes

    def data_generator():
        with h5py.File(h5_file, 'r') as hf:
            keys = list(hf.keys())
            if shuffle:
                np.random.shuffle(keys)

            for file in keys:
                group = hf[file]
                landmarks = group['landmarks'][:]
                label = group.attrs['label']  # read as string

                # convert label from string to integer index
                label_idx = class_to_index[label]

                # reshape landmarks to (frames, num_features)
                feature = landmarks.reshape(landmarks.shape[0], -1)

                yield feature, label_idx

    # get input shape from the first sample
    with h5py.File(h5_file, 'r') as hf:
        first_key = list(hf.keys())[0]
        first_landmarks = hf[first_key]['landmarks'][:]
        input_shape = (first_landmarks.shape[0], first_landmarks.shape[1])  # (frames, num_features)


    # create tf.data.Dataset
    dataset = tf.data.Dataset.from_generator(
        data_generator,
        output_signature = (
            tf.TensorSpec(shape = input_shape, dtype = tf.float32),
            tf.TensorSpec(shape = (), dtype = tf.int32)
        )
    )

    # apply shuffling, batching, and prefetching
    if shuffle:
        dataset = dataset.shuffle(buffer_size = 1000)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset, num_classes, input_shape, class_names

class PrintMetricsCallback(Callback):
    def on_epoch_end(self, epoch, logs = None):
        print(f"\nEpoch {epoch+1}: Training Accuracy = {logs['sparse_categorical_accuracy']:.4f}, Validation Accuracy = {logs['val_sparse_categorical_accuracy']:.4f}")

# compute class weights based on the training data
def get_class_weights(dataset, num_classes):
    # collect all labels from the dataset
    all_labels = []
    for _, label_batch in dataset:
        all_labels.extend(label_batch.numpy())  # Flatten the batch of labels

    # convert labels to a numpy array
    all_labels = np.array(all_labels)

    # ensure all classes are represented, even if some are missing in the dataset
    classes = np.arange(num_classes)

    # compute class weights
    class_weights = compute_class_weight('balanced', classes = classes, y = all_labels)

    return dict(enumerate(class_weights))


# load datasets
train_h5_path = "/content/drive/MyDrive/Colab Notebooks/Data/train_data.h5"
val_h5_path = "/content/drive/MyDrive/Colab Notebooks/Data/val_data.h5"

train_dataset, num_classes, input_shape, class_names = load_dataset_efficient(train_h5_path, batch_size = 16)
val_dataset, _, _, _ = load_dataset_efficient(val_h5_path, batch_size = 16, shuffle = False)

# get the class weights for the training dataset
class_weights = get_class_weights(train_dataset, num_classes)

# create model
model = create_model(input_shape, num_classes)

# callbacks
callbacks = [
    ModelCheckpoint("/content/drive/MyDrive/Colab Notebooks/Data/model_best.keras", save_best_only = True, monitor = 'val_sparse_categorical_accuracy', mode = 'max'),
    ReduceLROnPlateau(monitor = 'val_sparse_categorical_accuracy', factor = 0.7, patience = 5, mode = "max", min_lr = 1e-6),
    PrintMetricsCallback()
]

# train the model
history = model.fit(
    train_dataset,
    validation_data = val_dataset,
    epochs = 50,
    class_weight = class_weights,
    callbacks = callbacks
)
# Out:
# Epoch 1/50
#      50/Unknown 28s 15ms/step - loss: 2.3850 - sparse_categorical_accuracy: 0.3080
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 1: Training Accuracy = 0.4538, Validation Accuracy = 0.4950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 33s 101ms/step - loss: 2.3767 - sparse_categorical_accuracy: 0.3109 - val_loss: 1.5622 - val_sparse_categorical_accuracy: 0.4950 - learning_rate: 1.0000e-04
# Epoch 2/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0999 - sparse_categorical_accuracy: 0.7198
# Epoch 2: Training Accuracy = 0.7613, Validation Accuracy = 0.6350
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.0941 - sparse_categorical_accuracy: 0.7214 - val_loss: 1.0235 - val_sparse_categorical_accuracy: 0.6350 - learning_rate: 1.0000e-04
# Epoch 3/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5678 - sparse_categorical_accuracy: 0.8831
# Epoch 3: Training Accuracy = 0.8988, Validation Accuracy = 0.5650
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.5656 - sparse_categorical_accuracy: 0.8837 - val_loss: 1.9855 - val_sparse_categorical_accuracy: 0.5650 - learning_rate: 1.0000e-04
# Epoch 4/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3729 - sparse_categorical_accuracy: 0.9370
# Epoch 4: Training Accuracy = 0.9500, Validation Accuracy = 0.7250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.3718 - sparse_categorical_accuracy: 0.9376 - val_loss: 1.9167 - val_sparse_categorical_accuracy: 0.7250 - learning_rate: 1.0000e-04
# Epoch 5/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2890 - sparse_categorical_accuracy: 0.9621
# Epoch 5: Training Accuracy = 0.9700, Validation Accuracy = 0.8200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.6902 - val_sparse_categorical_accuracy: 0.8200 - learning_rate: 1.0000e-04
# Epoch 6/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2099 - sparse_categorical_accuracy: 0.9898
# Epoch 6: Training Accuracy = 0.9862, Validation Accuracy = 0.9100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2094 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.9100 - learning_rate: 1.0000e-04
# Epoch 7/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1751 - sparse_categorical_accuracy: 0.9895
# Epoch 7: Training Accuracy = 0.9912, Validation Accuracy = 0.9550
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1749 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.1834 - val_sparse_categorical_accuracy: 0.9550 - learning_rate: 1.0000e-04
# Epoch 8/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1390 - sparse_categorical_accuracy: 0.9981
# Epoch 8: Training Accuracy = 0.9937, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1392 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.1128 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 1.0000e-04
# Epoch 9/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1427 - sparse_categorical_accuracy: 0.9950
# Epoch 9: Training Accuracy = 0.9950, Validation Accuracy = 0.9650
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1425 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.2269 - val_sparse_categorical_accuracy: 0.9650 - learning_rate: 1.0000e-04
# Epoch 10/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9985
# Epoch 10: Training Accuracy = 0.9962, Validation Accuracy = 0.9450
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.3264 - val_sparse_categorical_accuracy: 0.9450 - learning_rate: 1.0000e-04
# Epoch 11/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9943
# Epoch 11: Training Accuracy = 0.9950, Validation Accuracy = 0.9100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.4017 - val_sparse_categorical_accuracy: 0.9100 - learning_rate: 1.0000e-04
# Epoch 12/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1135 - sparse_categorical_accuracy: 0.9978
# Epoch 12: Training Accuracy = 0.9937, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1137 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0880 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1228 - sparse_categorical_accuracy: 0.9930
# Epoch 13: Training Accuracy = 0.9937, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.0912 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 1.0000e-04
# Epoch 14/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1030 - sparse_categorical_accuracy: 0.9989
# Epoch 14: Training Accuracy = 0.9975, Validation Accuracy = 0.9900
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1030 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9900 - learning_rate: 1.0000e-04
# Epoch 15/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1051 - sparse_categorical_accuracy: 1.0000
# Epoch 15: Training Accuracy = 1.0000, Validation Accuracy = 0.9500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1050 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9500 - learning_rate: 1.0000e-04
# Epoch 16/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0984 - sparse_categorical_accuracy: 1.0000
# Epoch 16: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0984 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 17/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0969 - sparse_categorical_accuracy: 1.0000
# Epoch 17: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0970 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.0000e-04
# Epoch 18/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0965 - sparse_categorical_accuracy: 1.0000
# Epoch 18: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0966 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0842 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 7.0000e-05
# Epoch 19/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0965 - sparse_categorical_accuracy: 1.0000
# Epoch 19: Training Accuracy = 1.0000, Validation Accuracy = 0.9850
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0966 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1371 - val_sparse_categorical_accuracy: 0.9850 - learning_rate: 7.0000e-05
# Epoch 20/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0969 - sparse_categorical_accuracy: 1.0000
# Epoch 20: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0969 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0839 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 7.0000e-05
# Epoch 21/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0948 - sparse_categorical_accuracy: 1.0000
# Epoch 21: Training Accuracy = 1.0000, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0948 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 7.0000e-05
# Epoch 22/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0985 - sparse_categorical_accuracy: 1.0000
# Epoch 22: Training Accuracy = 1.0000, Validation Accuracy = 0.9650
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0984 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2664 - val_sparse_categorical_accuracy: 0.9650 - learning_rate: 7.0000e-05
# Epoch 23/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9995
# Epoch 23: Training Accuracy = 0.9987, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0904 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 4.9000e-05
# Epoch 24/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9980
# Epoch 24: Training Accuracy = 0.9987, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 4.9000e-05
# Epoch 25/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0898 - sparse_categorical_accuracy: 1.0000
# Epoch 25: Training Accuracy = 1.0000, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0898 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0896 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 4.9000e-05
# Epoch 26/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0936 - sparse_categorical_accuracy: 1.0000
# Epoch 26: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0936 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0852 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 4.9000e-05
# Epoch 27/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9997
# Epoch 27: Training Accuracy = 0.9987, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0826 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 4.9000e-05
# Epoch 28/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0927 - sparse_categorical_accuracy: 1.0000
# Epoch 28: Training Accuracy = 1.0000, Validation Accuracy = 0.9800
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0926 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1117 - val_sparse_categorical_accuracy: 0.9800 - learning_rate: 3.4300e-05
# Epoch 29/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0942 - sparse_categorical_accuracy: 1.0000
# Epoch 29: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0941 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0839 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 3.4300e-05
# Epoch 30/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0905 - sparse_categorical_accuracy: 1.0000
# Epoch 30: Training Accuracy = 1.0000, Validation Accuracy = 0.9850
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0906 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1852 - val_sparse_categorical_accuracy: 0.9850 - learning_rate: 3.4300e-05
# Epoch 31/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0910 - sparse_categorical_accuracy: 1.0000
# Epoch 31: Training Accuracy = 1.0000, Validation Accuracy = 0.9900
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0910 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1023 - val_sparse_categorical_accuracy: 0.9900 - learning_rate: 3.4300e-05
# Epoch 32/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0930 - sparse_categorical_accuracy: 1.0000
# Epoch 32: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0930 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0820 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 3.4300e-05
# Epoch 33/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0888 - sparse_categorical_accuracy: 1.0000
# Epoch 33: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0888 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0827 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 2.4010e-05
# Epoch 34/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0922 - sparse_categorical_accuracy: 1.0000
# Epoch 34: Training Accuracy = 1.0000, Validation Accuracy = 0.9900
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0922 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9900 - learning_rate: 2.4010e-05
# Epoch 35/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0908 - sparse_categorical_accuracy: 1.0000
# Epoch 35: Training Accuracy = 1.0000, Validation Accuracy = 0.9950
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0908 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0884 - val_sparse_categorical_accuracy: 0.9950 - learning_rate: 2.4010e-05
# Epoch 36/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0868 - sparse_categorical_accuracy: 1.0000
# Epoch 36: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0869 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 2.4010e-05
# Epoch 37/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0890 - sparse_categorical_accuracy: 1.0000
# Epoch 37: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0890 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0815 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 2.4010e-05
# Epoch 38/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0869 - sparse_categorical_accuracy: 1.0000
# Epoch 38: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0869 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.6807e-05
# Epoch 39/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0880 - sparse_categorical_accuracy: 1.0000
# Epoch 39: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0879 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0813 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.6807e-05
# Epoch 40/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0872 - sparse_categorical_accuracy: 1.0000
# Epoch 40: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0872 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.6807e-05
# Epoch 41/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0906 - sparse_categorical_accuracy: 1.0000
# Epoch 41: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0905 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0811 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.6807e-05
# Epoch 42/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0877 - sparse_categorical_accuracy: 1.0000
# Epoch 42: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0877 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.6807e-05
# Epoch 43/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0886 - sparse_categorical_accuracy: 1.0000
# Epoch 43: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0886 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.1765e-05
# Epoch 44/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0866 - sparse_categorical_accuracy: 1.0000
# Epoch 44: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0866 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0809 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.1765e-05
# Epoch 45/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0870 - sparse_categorical_accuracy: 1.0000
# Epoch 45: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0870 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0808 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.1765e-05
# Epoch 46/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0873 - sparse_categorical_accuracy: 1.0000
# Epoch 46: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0873 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0808 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.1765e-05
# Epoch 47/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0863 - sparse_categorical_accuracy: 1.0000
# Epoch 47: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0863 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 1.1765e-05
# Epoch 48/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0888 - sparse_categorical_accuracy: 0.9998
# Epoch 48: Training Accuracy = 0.9987, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0806 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 8.2354e-06
# Epoch 49/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0886 - sparse_categorical_accuracy: 1.0000
# Epoch 49: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0885 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0806 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 8.2354e-06
# Epoch 50/50
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0862 - sparse_categorical_accuracy: 1.0000
# Epoch 50: Training Accuracy = 1.0000, Validation Accuracy = 1.0000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0862 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0805 - val_sparse_categorical_accuracy: 1.0000 - learning_rate: 8.2354e-06

# %% [markdown]
# save the model history

# %%
with open("/content/drive/MyDrive/Colab Notebooks/Data/history.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %% [markdown]
# # Testing the Model

# %% [markdown]
# preparing the test dataset

# %%
def extract_uppercase_name(filename):
  # extracts only the uppercase words at the front of the file - name of the gestures
  base_name = os.path.basename(filename).split('.')[0]  # get only the name without extenstion
  match = re.match(r'^([A-Z_]+)', base_name) # get uppercase words at the start
  return match.group(1) if match else base_name  # return words or not return whole name

def create_test_set(gif_files, output_folder, samples_per_file = 30):
    # create the output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # loop through each file in the input gif files list
    for file_path, file_name in gif_files:
        # extract the base name
        base_name = extract_uppercase_name(file_name)

        # create 30 copies of each file
        for i in range(samples_per_file):
            # generate a new name with suffix
            new_file_name = f"{base_name}_test_{i+1}.gif"
            dest_path = os.path.join(output_folder, new_file_name)

            # copy the file with the new name
            shutil.copy(file_path, dest_path)

        print(f"Copied {samples_per_file} copies of {file_name} to {output_folder}")

# get all gif files from the input folder
gif_files = [(os.path.join(input_folder, file), file) for file in os.listdir(input_folder) if file.endswith(".gif")]

# output test folder
output_test_folder = "/content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/"

create_test_set(gif_files, output_test_folder, samples_per_file = 30)
# Out:
# Copied 30 copies of D.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of C.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of B.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of A.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of MONEY-A.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of DRINKa.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of GO.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of BOOK_(n).gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of MAKE.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of SCHOOL_(Noun).gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of WATER.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of EATa.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of READ.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of YOU.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of MY.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of I_2.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of HOW_ARE_YOU.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of HELLO.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of FOOD.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/
# Copied 30 copies of E.gif to /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/

# %%
# output test folder
output_test_folder = "/content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/"

# get data from both test ouput folder
test_dataset = SGSL_Dataset(folder = output_test_folder, batch_size = 32, max_frames = 50)

# preprocess and store the testing data
test_dataset.preprocess_and_store("/content/drive/MyDrive/Colab Notebooks/Data/test_data.h5")

# print information about the dataset
test_dataset.print_dataset_info()
# Out:
# Processing GIF 1/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_1.gif
# Total frames in GIF: 135
# Processing GIF 2/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_2.gif
# Total frames in GIF: 135
# Processing GIF 3/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_3.gif
# Total frames in GIF: 135
# Processing GIF 4/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_4.gif
# Total frames in GIF: 135
# Processing GIF 5/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_5.gif
# Total frames in GIF: 135
# Processing GIF 6/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_6.gif
# Total frames in GIF: 135
# Processing GIF 7/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_7.gif
# Total frames in GIF: 135
# Processing GIF 8/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_8.gif
# Total frames in GIF: 135
# Processing GIF 9/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_9.gif
# Total frames in GIF: 135
# Processing GIF 10/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_10.gif
# Total frames in GIF: 135
# Processing GIF 11/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_11.gif
# Total frames in GIF: 135
# Processing GIF 12/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_12.gif
# Total frames in GIF: 135
# Processing GIF 13/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_13.gif
# Total frames in GIF: 135
# Processing GIF 14/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_14.gif
# Total frames in GIF: 135
# Processing GIF 15/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_15.gif
# Total frames in GIF: 135
# Processing GIF 16/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_16.gif
# Total frames in GIF: 135
# Processing GIF 17/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_17.gif
# Total frames in GIF: 135
# Processing GIF 18/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_18.gif
# Total frames in GIF: 135
# Processing GIF 19/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_19.gif
# Total frames in GIF: 135
# Processing GIF 20/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_20.gif
# Total frames in GIF: 135
# Processing GIF 21/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_21.gif
# Total frames in GIF: 135
# Processing GIF 22/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_22.gif
# Total frames in GIF: 135
# Processing GIF 23/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_23.gif
# Total frames in GIF: 135
# Processing GIF 24/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_24.gif
# Total frames in GIF: 135
# Processing GIF 25/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_25.gif
# Total frames in GIF: 135
# Processing GIF 26/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_26.gif
# Total frames in GIF: 135
# Processing GIF 27/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_27.gif
# Total frames in GIF: 135
# Processing GIF 28/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_28.gif
# Total frames in GIF: 135
# Processing GIF 29/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_29.gif
# Total frames in GIF: 135
# Processing GIF 30/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/D_test_30.gif
# Total frames in GIF: 135
# Processing GIF 31/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_1.gif
# Total frames in GIF: 164
# Processing GIF 32/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_2.gif
# Total frames in GIF: 164
# Processing GIF 33/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_3.gif
# Total frames in GIF: 164
# Processing GIF 34/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_4.gif
# Total frames in GIF: 164
# Processing GIF 35/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_5.gif
# Total frames in GIF: 164
# Processing GIF 36/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_6.gif
# Total frames in GIF: 164
# Processing GIF 37/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_7.gif
# Total frames in GIF: 164
# Processing GIF 38/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_8.gif
# Total frames in GIF: 164
# Processing GIF 39/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_9.gif
# Total frames in GIF: 164
# Processing GIF 40/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_10.gif
# Total frames in GIF: 164
# Processing GIF 41/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_11.gif
# Total frames in GIF: 164
# Processing GIF 42/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_12.gif
# Total frames in GIF: 164
# Processing GIF 43/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_13.gif
# Total frames in GIF: 164
# Processing GIF 44/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_14.gif
# Total frames in GIF: 164
# Processing GIF 45/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_15.gif
# Total frames in GIF: 164
# Processing GIF 46/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_16.gif
# Total frames in GIF: 164
# Processing GIF 47/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_17.gif
# Total frames in GIF: 164
# Processing GIF 48/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_18.gif
# Total frames in GIF: 164
# Processing GIF 49/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_19.gif
# Total frames in GIF: 164
# Processing GIF 50/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_20.gif
# Total frames in GIF: 164
# Processing GIF 51/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_21.gif
# Total frames in GIF: 164
# Processing GIF 52/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_22.gif
# Total frames in GIF: 164
# Processing GIF 53/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_23.gif
# Total frames in GIF: 164
# Processing GIF 54/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_24.gif
# Total frames in GIF: 164
# Processing GIF 55/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_25.gif
# Total frames in GIF: 164
# Processing GIF 56/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_26.gif
# Total frames in GIF: 164
# Processing GIF 57/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_27.gif
# Total frames in GIF: 164
# Processing GIF 58/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_28.gif
# Total frames in GIF: 164
# Processing GIF 59/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_29.gif
# Total frames in GIF: 164
# Processing GIF 60/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/C_test_30.gif
# Total frames in GIF: 164
# Processing GIF 61/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_1.gif
# Total frames in GIF: 165
# Processing GIF 62/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_2.gif
# Total frames in GIF: 165
# Processing GIF 63/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_3.gif
# Total frames in GIF: 165
# Processing GIF 64/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_4.gif
# Total frames in GIF: 165
# Processing GIF 65/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_5.gif
# Total frames in GIF: 165
# Processing GIF 66/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_6.gif
# Total frames in GIF: 165
# Processing GIF 67/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_7.gif
# Total frames in GIF: 165
# Processing GIF 68/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_8.gif
# Total frames in GIF: 165
# Processing GIF 69/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_9.gif
# Total frames in GIF: 165
# Processing GIF 70/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_10.gif
# Total frames in GIF: 165
# Processing GIF 71/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_11.gif
# Total frames in GIF: 165
# Processing GIF 72/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_12.gif
# Total frames in GIF: 165
# Processing GIF 73/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_13.gif
# Total frames in GIF: 165
# Processing GIF 74/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_14.gif
# Total frames in GIF: 165
# Processing GIF 75/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_15.gif
# Total frames in GIF: 165
# Processing GIF 76/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_16.gif
# Total frames in GIF: 165
# Processing GIF 77/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_17.gif
# Total frames in GIF: 165
# Processing GIF 78/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_18.gif
# Total frames in GIF: 165
# Processing GIF 79/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_19.gif
# Total frames in GIF: 165
# Processing GIF 80/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_20.gif
# Total frames in GIF: 165
# Processing GIF 81/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_21.gif
# Total frames in GIF: 165
# Processing GIF 82/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_22.gif
# Total frames in GIF: 165
# Processing GIF 83/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_23.gif
# Total frames in GIF: 165
# Processing GIF 84/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_24.gif
# Total frames in GIF: 165
# Processing GIF 85/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_25.gif
# Total frames in GIF: 165
# Processing GIF 86/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_26.gif
# Total frames in GIF: 165
# Processing GIF 87/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_27.gif
# Total frames in GIF: 165
# Processing GIF 88/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_28.gif
# Total frames in GIF: 165
# Processing GIF 89/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_29.gif
# Total frames in GIF: 165
# Processing GIF 90/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/B_test_30.gif
# Total frames in GIF: 165
# Processing GIF 91/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_1.gif
# Total frames in GIF: 149
# Processing GIF 92/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_2.gif
# Total frames in GIF: 149
# Processing GIF 93/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_3.gif
# Total frames in GIF: 149
# Processing GIF 94/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_4.gif
# Total frames in GIF: 149
# Processing GIF 95/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_5.gif
# Total frames in GIF: 149
# Processing GIF 96/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_6.gif
# Total frames in GIF: 149
# Processing GIF 97/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_7.gif
# Total frames in GIF: 149
# Processing GIF 98/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_8.gif
# Total frames in GIF: 149
# Processing GIF 99/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_9.gif
# Total frames in GIF: 149
# Processing GIF 100/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_10.gif
# Total frames in GIF: 149
# Processing GIF 101/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_11.gif
# Total frames in GIF: 149
# Processing GIF 102/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_12.gif
# Total frames in GIF: 149
# Processing GIF 103/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_13.gif
# Total frames in GIF: 149
# Processing GIF 104/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_14.gif
# Total frames in GIF: 149
# Processing GIF 105/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_15.gif
# Total frames in GIF: 149
# Processing GIF 106/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_16.gif
# Total frames in GIF: 149
# Processing GIF 107/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_17.gif
# Total frames in GIF: 149
# Processing GIF 108/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_18.gif
# Total frames in GIF: 149
# Processing GIF 109/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_19.gif
# Total frames in GIF: 149
# Processing GIF 110/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_20.gif
# Total frames in GIF: 149
# Processing GIF 111/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_21.gif
# Total frames in GIF: 149
# Processing GIF 112/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_22.gif
# Total frames in GIF: 149
# Processing GIF 113/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_23.gif
# Total frames in GIF: 149
# Processing GIF 114/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_24.gif
# Total frames in GIF: 149
# Processing GIF 115/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_25.gif
# Total frames in GIF: 149
# Processing GIF 116/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_26.gif
# Total frames in GIF: 149
# Processing GIF 117/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_27.gif
# Total frames in GIF: 149
# Processing GIF 118/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_28.gif
# Total frames in GIF: 149
# Processing GIF 119/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_29.gif
# Total frames in GIF: 149
# Processing GIF 120/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/A_test_30.gif
# Total frames in GIF: 149
# Processing GIF 121/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_1.gif
# Total frames in GIF: 41
# Processing GIF 122/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_2.gif
# Total frames in GIF: 41
# Processing GIF 123/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_3.gif
# Total frames in GIF: 41
# Processing GIF 124/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_4.gif
# Total frames in GIF: 41
# Processing GIF 125/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_5.gif
# Total frames in GIF: 41
# Processing GIF 126/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_6.gif
# Total frames in GIF: 41
# Processing GIF 127/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_7.gif
# Total frames in GIF: 41
# Processing GIF 128/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_8.gif
# Total frames in GIF: 41
# Processing GIF 129/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_9.gif
# Total frames in GIF: 41
# Processing GIF 130/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_10.gif
# Total frames in GIF: 41
# Processing GIF 131/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_11.gif
# Total frames in GIF: 41
# Processing GIF 132/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_12.gif
# Total frames in GIF: 41
# Processing GIF 133/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_13.gif
# Total frames in GIF: 41
# Processing GIF 134/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_14.gif
# Total frames in GIF: 41
# Processing GIF 135/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_15.gif
# Total frames in GIF: 41
# Processing GIF 136/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_16.gif
# Total frames in GIF: 41
# Processing GIF 137/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_17.gif
# Total frames in GIF: 41
# Processing GIF 138/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_18.gif
# Total frames in GIF: 41
# Processing GIF 139/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_19.gif
# Total frames in GIF: 41
# Processing GIF 140/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_20.gif
# Total frames in GIF: 41
# Processing GIF 141/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_21.gif
# Total frames in GIF: 41
# Processing GIF 142/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_22.gif
# Total frames in GIF: 41
# Processing GIF 143/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_23.gif
# Total frames in GIF: 41
# Processing GIF 144/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_24.gif
# Total frames in GIF: 41
# Processing GIF 145/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_25.gif
# Total frames in GIF: 41
# Processing GIF 146/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_26.gif
# Total frames in GIF: 41
# Processing GIF 147/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_27.gif
# Total frames in GIF: 41
# Processing GIF 148/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_28.gif
# Total frames in GIF: 41
# Processing GIF 149/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_29.gif
# Total frames in GIF: 41
# Processing GIF 150/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/MONEY_test_30.gif
# Total frames in GIF: 41
# Processing GIF 151/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_1.gif
# Total frames in GIF: 31
# Processing GIF 152/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_2.gif
# Total frames in GIF: 31
# Processing GIF 153/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_3.gif
# Total frames in GIF: 31
# Processing GIF 154/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_4.gif
# Total frames in GIF: 31
# Processing GIF 155/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_5.gif
# Total frames in GIF: 31
# Processing GIF 156/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_6.gif
# Total frames in GIF: 31
# Processing GIF 157/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_7.gif
# Total frames in GIF: 31
# Processing GIF 158/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_8.gif
# Total frames in GIF: 31
# Processing GIF 159/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_9.gif
# Total frames in GIF: 31
# Processing GIF 160/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_10.gif
# Total frames in GIF: 31
# Processing GIF 161/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_11.gif
# Total frames in GIF: 31
# Processing GIF 162/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_12.gif
# Total frames in GIF: 31
# Processing GIF 163/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_13.gif
# Total frames in GIF: 31
# Processing GIF 164/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_14.gif
# Total frames in GIF: 31
# Processing GIF 165/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_15.gif
# Total frames in GIF: 31
# Processing GIF 166/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_16.gif
# Total frames in GIF: 31
# Processing GIF 167/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_17.gif
# Total frames in GIF: 31
# Processing GIF 168/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_18.gif
# Total frames in GIF: 31
# Processing GIF 169/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_19.gif
# Total frames in GIF: 31
# Processing GIF 170/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_20.gif
# Total frames in GIF: 31
# Processing GIF 171/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_21.gif
# Total frames in GIF: 31
# Processing GIF 172/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_22.gif
# Total frames in GIF: 31
# Processing GIF 173/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_23.gif
# Total frames in GIF: 31
# Processing GIF 174/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_24.gif
# Total frames in GIF: 31
# Processing GIF 175/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_25.gif
# Total frames in GIF: 31
# Processing GIF 176/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_26.gif
# Total frames in GIF: 31
# Processing GIF 177/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_27.gif
# Total frames in GIF: 31
# Processing GIF 178/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_28.gif
# Total frames in GIF: 31
# Processing GIF 179/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_29.gif
# Total frames in GIF: 31
# Processing GIF 180/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/DRINK_test_30.gif
# Total frames in GIF: 31
# Processing GIF 181/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_1.gif
# Total frames in GIF: 17
# Processing GIF 182/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_2.gif
# Total frames in GIF: 17
# Processing GIF 183/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_3.gif
# Total frames in GIF: 17
# Processing GIF 184/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_4.gif
# Total frames in GIF: 17
# Processing GIF 185/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_5.gif
# Total frames in GIF: 17
# Processing GIF 186/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_6.gif
# Total frames in GIF: 17
# Processing GIF 187/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_7.gif
# Total frames in GIF: 17
# Processing GIF 188/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_8.gif
# Total frames in GIF: 17
# Processing GIF 189/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_9.gif
# Total frames in GIF: 17
# Processing GIF 190/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_10.gif
# Total frames in GIF: 17
# Processing GIF 191/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_11.gif
# Total frames in GIF: 17
# Processing GIF 192/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_12.gif
# Total frames in GIF: 17
# Processing GIF 193/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_13.gif
# Total frames in GIF: 17
# Processing GIF 194/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_14.gif
# Total frames in GIF: 17
# Processing GIF 195/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_15.gif
# Total frames in GIF: 17
# Processing GIF 196/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_16.gif
# Total frames in GIF: 17
# Processing GIF 197/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_17.gif
# Total frames in GIF: 17
# Processing GIF 198/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_18.gif
# Total frames in GIF: 17
# Processing GIF 199/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_19.gif
# Total frames in GIF: 17
# Processing GIF 200/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_20.gif
# Total frames in GIF: 17
# Processing GIF 201/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_21.gif
# Total frames in GIF: 17
# Processing GIF 202/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_22.gif
# Total frames in GIF: 17
# Processing GIF 203/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_23.gif
# Total frames in GIF: 17
# Processing GIF 204/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_24.gif
# Total frames in GIF: 17
# Processing GIF 205/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_25.gif
# Total frames in GIF: 17
# Processing GIF 206/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_26.gif
# Total frames in GIF: 17
# Processing GIF 207/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_27.gif
# Total frames in GIF: 17
# Processing GIF 208/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_28.gif
# Total frames in GIF: 17
# Processing GIF 209/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_29.gif
# Total frames in GIF: 17
# Processing GIF 210/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/GO_test_30.gif
# Total frames in GIF: 17
# Processing GIF 211/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_1.gif
# Total frames in GIF: 47
# Processing GIF 212/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_2.gif
# Total frames in GIF: 47
# Processing GIF 213/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_3.gif
# Total frames in GIF: 47
# Processing GIF 214/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_4.gif
# Total frames in GIF: 47
# Processing GIF 215/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_5.gif
# Total frames in GIF: 47
# Processing GIF 216/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_6.gif
# Total frames in GIF: 47
# Processing GIF 217/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_7.gif
# Total frames in GIF: 47
# Processing GIF 218/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_8.gif
# Total frames in GIF: 47
# Processing GIF 219/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_9.gif
# Total frames in GIF: 47
# Processing GIF 220/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_10.gif
# Total frames in GIF: 47
# Processing GIF 221/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_11.gif
# Total frames in GIF: 47
# Processing GIF 222/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_12.gif
# Total frames in GIF: 47
# Processing GIF 223/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_13.gif
# Total frames in GIF: 47
# Processing GIF 224/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_14.gif
# Total frames in GIF: 47
# Processing GIF 225/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_15.gif
# Total frames in GIF: 47
# Processing GIF 226/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_16.gif
# Total frames in GIF: 47
# Processing GIF 227/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_17.gif
# Total frames in GIF: 47
# Processing GIF 228/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_18.gif
# Total frames in GIF: 47
# Processing GIF 229/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_19.gif
# Total frames in GIF: 47
# Processing GIF 230/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_20.gif
# Total frames in GIF: 47
# Processing GIF 231/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_21.gif
# Total frames in GIF: 47
# Processing GIF 232/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_22.gif
# Total frames in GIF: 47
# Processing GIF 233/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_23.gif
# Total frames in GIF: 47
# Processing GIF 234/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_24.gif
# Total frames in GIF: 47
# Processing GIF 235/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_25.gif
# Total frames in GIF: 47
# Processing GIF 236/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_26.gif
# Total frames in GIF: 47
# Processing GIF 237/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/BOOK__test_27.gif
# ...
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_14.gif
# Total frames in GIF: 74
# Processing GIF 525/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_15.gif
# Total frames in GIF: 74
# Processing GIF 526/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_16.gif
# Total frames in GIF: 74
# Processing GIF 527/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_17.gif
# Total frames in GIF: 74
# Processing GIF 528/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_18.gif
# Total frames in GIF: 74
# Processing GIF 529/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_19.gif
# Total frames in GIF: 74
# Processing GIF 530/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_20.gif
# Total frames in GIF: 74
# Processing GIF 531/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_21.gif
# Total frames in GIF: 74
# Processing GIF 532/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_22.gif
# Total frames in GIF: 74
# Processing GIF 533/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_23.gif
# Total frames in GIF: 74
# Processing GIF 534/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_24.gif
# Total frames in GIF: 74
# Processing GIF 535/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_25.gif
# Total frames in GIF: 74
# Processing GIF 536/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_26.gif
# Total frames in GIF: 74
# Processing GIF 537/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_27.gif
# Total frames in GIF: 74
# Processing GIF 538/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_28.gif
# Total frames in GIF: 74
# Processing GIF 539/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_29.gif
# Total frames in GIF: 74
# Processing GIF 540/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/HELLO_test_30.gif
# Total frames in GIF: 74
# Processing GIF 541/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_1.gif
# Total frames in GIF: 42
# Processing GIF 542/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_2.gif
# Total frames in GIF: 42
# Processing GIF 543/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_3.gif
# Total frames in GIF: 42
# Processing GIF 544/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_4.gif
# Total frames in GIF: 42
# Processing GIF 545/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_5.gif
# Total frames in GIF: 42
# Processing GIF 546/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_6.gif
# Total frames in GIF: 42
# Processing GIF 547/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_7.gif
# Total frames in GIF: 42
# Processing GIF 548/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_8.gif
# Total frames in GIF: 42
# Processing GIF 549/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_9.gif
# Total frames in GIF: 42
# Processing GIF 550/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_10.gif
# Total frames in GIF: 42
# Processing GIF 551/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_11.gif
# Total frames in GIF: 42
# Processing GIF 552/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_12.gif
# Total frames in GIF: 42
# Processing GIF 553/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_13.gif
# Total frames in GIF: 42
# Processing GIF 554/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_14.gif
# Total frames in GIF: 42
# Processing GIF 555/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_15.gif
# Total frames in GIF: 42
# Processing GIF 556/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_16.gif
# Total frames in GIF: 42
# Processing GIF 557/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_17.gif
# Total frames in GIF: 42
# Processing GIF 558/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_18.gif
# Total frames in GIF: 42
# Processing GIF 559/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_19.gif
# Total frames in GIF: 42
# Processing GIF 560/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_20.gif
# Total frames in GIF: 42
# Processing GIF 561/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_21.gif
# Total frames in GIF: 42
# Processing GIF 562/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_22.gif
# Total frames in GIF: 42
# Processing GIF 563/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_23.gif
# Total frames in GIF: 42
# Processing GIF 564/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_24.gif
# Total frames in GIF: 42
# Processing GIF 565/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_25.gif
# Total frames in GIF: 42
# Processing GIF 566/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_26.gif
# Total frames in GIF: 42
# Processing GIF 567/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_27.gif
# Total frames in GIF: 42
# Processing GIF 568/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_28.gif
# Total frames in GIF: 42
# Processing GIF 569/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_29.gif
# Total frames in GIF: 42
# Processing GIF 570/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/FOOD_test_30.gif
# Total frames in GIF: 42
# Processing GIF 571/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_1.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_1.gif
# Total frames in GIF: 149
# Processing GIF 572/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_2.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_2.gif
# Total frames in GIF: 149
# Processing GIF 573/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_3.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_3.gif
# Total frames in GIF: 149
# Processing GIF 574/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_4.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_4.gif
# Total frames in GIF: 149
# Processing GIF 575/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_5.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_5.gif
# Total frames in GIF: 149
# Processing GIF 576/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_6.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_6.gif
# Total frames in GIF: 149
# Processing GIF 577/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_7.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_7.gif
# Total frames in GIF: 149
# Processing GIF 578/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_8.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_8.gif
# Total frames in GIF: 149
# Processing GIF 579/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_9.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_9.gif
# Total frames in GIF: 149
# Processing GIF 580/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_10.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_10.gif
# Total frames in GIF: 149
# Processing GIF 581/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_11.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_11.gif
# Total frames in GIF: 149
# Processing GIF 582/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_12.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_12.gif
# Total frames in GIF: 149
# Processing GIF 583/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_13.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_13.gif
# Total frames in GIF: 149
# Processing GIF 584/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_14.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_14.gif
# Total frames in GIF: 149
# Processing GIF 585/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_15.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_15.gif
# Total frames in GIF: 149
# Processing GIF 586/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_16.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_16.gif
# Total frames in GIF: 149
# Processing GIF 587/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_17.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_17.gif
# Total frames in GIF: 149
# Processing GIF 588/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_18.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_18.gif
# Total frames in GIF: 149
# Processing GIF 589/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_19.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_19.gif
# Total frames in GIF: 149
# Processing GIF 590/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_20.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_20.gif
# Total frames in GIF: 149
# Processing GIF 591/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_21.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_21.gif
# Total frames in GIF: 149
# Processing GIF 592/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_22.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_22.gif
# Total frames in GIF: 149
# Processing GIF 593/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_23.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_23.gif
# Total frames in GIF: 149
# Processing GIF 594/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_24.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_24.gif
# Total frames in GIF: 149
# Processing GIF 595/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_25.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_25.gif
# Total frames in GIF: 149
# Processing GIF 596/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_26.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_26.gif
# Total frames in GIF: 149
# Processing GIF 597/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_27.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_27.gif
# Total frames in GIF: 149
# Processing GIF 598/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_28.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_28.gif
# Total frames in GIF: 149
# Processing GIF 599/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_29.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_29.gif
# Total frames in GIF: 149
# Processing GIF 600/600: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_30.gif
# Processing GIF: /content/drive/MyDrive/Colab Notebooks/Data/test_sgsl/E_test_30.gif
# Total frames in GIF: 149
# Preprocessed data saved to /content/drive/MyDrive/Colab Notebooks/Data/test_data.h5
# Number of unique labels (classes): 20
# Class distribution: {'A': 30, 'B': 30, 'BOOK': 30, 'C': 30, 'D': 30, 'DRINK': 30, 'E': 30, 'EAT': 30, 'FOOD': 30, 'GO': 30, 'HELLO': 30, 'HOW ARE YOU': 30, 'I': 30, 'MAKE': 30, 'MONEY': 30, 'MY': 30, 'READ': 30, 'SCHOOL': 30, 'WATER': 30, 'YOU': 30}

# %% [markdown]
# load model and test

# %%
# dataset loader
def load_dataset_efficient(h5_file, batch_size = 16, shuffle = True):
    # read all labels and create a mapping from class names to integer indices
    with h5py.File(h5_file, 'r') as hf:
        all_labels = [hf[k].attrs['label'].decode() if isinstance(hf[k].attrs['label'], bytes) else hf[k].attrs['label'] for k in hf.keys()]
        class_names = sorted(set(all_labels))  # get unique class names, sorted
        class_to_index = {name: idx for idx, name in enumerate(class_names)}  # mapping

    num_classes = len(class_names)  # total number of classes

    def data_generator():
        with h5py.File(h5_file, 'r') as hf:
            keys = list(hf.keys())
            if shuffle:
                np.random.shuffle(keys)

            for file in keys:
                group = hf[file]
                landmarks = group['landmarks'][:]
                label = group.attrs['label']  # read as string

                # convert label from string to integer index
                label_idx = class_to_index[label]

                # reshape landmarks to (frames, num_features)
                feature = landmarks.reshape(landmarks.shape[0], -1)

                yield feature, label_idx

    # get input shape from the first sample
    with h5py.File(h5_file, 'r') as hf:
        first_key = list(hf.keys())[0]
        first_landmarks = hf[first_key]['landmarks'][:]
        input_shape = (first_landmarks.shape[0], first_landmarks.shape[1])  # (frames, num_features)


    # create tf.data.Dataset
    dataset = tf.data.Dataset.from_generator(
        data_generator,
        output_signature = (
            tf.TensorSpec(shape = input_shape, dtype = tf.float32),
            tf.TensorSpec(shape = (), dtype = tf.int32)
        )
    )

    # apply shuffling, batching, and prefetching
    if shuffle:
        dataset = dataset.shuffle(buffer_size = 1000)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset, num_classes, input_shape, class_names

# load test dataset
test_h5_path = "/content/drive/MyDrive/Colab Notebooks/Data/test_data.h5"

test_dataset, num_classes, input_shape, class_names = load_dataset_efficient(test_h5_path, batch_size = 16, shuffle = False)

# load the saved model
model = load_model('/content/drive/MyDrive/Colab Notebooks/Data/model_best.keras')

# evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_dataset, verbose = 1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.1433 - sparse_categorical_accuracy: 0.9736
# Test Loss: 0.11901228874921799
# Test Accuracy: 0.9850000143051147

# %% [markdown]
# # Model Visualizations

# %% [markdown]
# load history and model

# %%
# load the training history
history_path = "/content/drive/MyDrive/Colab Notebooks/Data/history.pkl"
with open(history_path, "rb") as f:
    history = pickle.load(f)

# load the trained model
model = tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/Data/model_best.keras")

# dataset loader
def load_dataset_efficient(h5_file, batch_size = 16, shuffle = True):
    # read all labels and create a mapping from class names to integer indices
    with h5py.File(h5_file, 'r') as hf:
        all_labels = [hf[k].attrs['label'].decode() if isinstance(hf[k].attrs['label'], bytes) else hf[k].attrs['label'] for k in hf.keys()]
        class_names = sorted(set(all_labels))  # get unique class names, sorted
        class_to_index = {name: idx for idx, name in enumerate(class_names)}  # mapping

    num_classes = len(class_names)  # total number of classes

    def data_generator():
        with h5py.File(h5_file, 'r') as hf:
            keys = list(hf.keys())
            if shuffle:
                np.random.shuffle(keys)

            for file in keys:
                group = hf[file]
                landmarks = group['landmarks'][:]
                label = group.attrs['label']  # read as string

                # convert label from string to integer index
                label_idx = class_to_index[label]

                # reshape landmarks to (frames, num_features)
                feature = landmarks.reshape(landmarks.shape[0], -1)

                yield feature, label_idx

    # get input shape from the first sample
    with h5py.File(h5_file, 'r') as hf:
        first_key = list(hf.keys())[0]
        first_landmarks = hf[first_key]['landmarks'][:]
        input_shape = (first_landmarks.shape[0], first_landmarks.shape[1])  # (frames, num_features)


    # create tf.data.Dataset
    dataset = tf.data.Dataset.from_generator(
        data_generator,
        output_signature = (
            tf.TensorSpec(shape = input_shape, dtype = tf.float32),
            tf.TensorSpec(shape = (), dtype = tf.int32)
        )
    )

    # apply shuffling, batching, and prefetching
    if shuffle:
        dataset = dataset.shuffle(buffer_size = 1000)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

    return dataset, num_classes, input_shape, class_names

# load test dataset
test_h5_path = "/content/drive/MyDrive/Colab Notebooks/Data/test_data.h5"  # Update with the correct path to your test data
test_dataset, _, _, class_names = load_dataset_efficient(test_h5_path, batch_size = 32, shuffle = False)

# get ground truth and predictions
y_true = []
y_pred = []

for x_batch, y_batch in test_dataset:
    preds = model.predict(x_batch)
    y_pred.extend(np.argmax(preds, axis = 1))
    y_true.extend(y_batch.numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# training vs validation accuracy

# %%
plt.figure(figsize=(8, 5))
plt.plot(history['sparse_categorical_accuracy'], label = "Train Accuracy", color = 'blue')
plt.plot(history['val_sparse_categorical_accuracy'], label = "Val Accuracy", color = 'orange')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# training vs validation loss

# %%
plt.figure(figsize=(8, 5))
plt.plot(history['loss'], label = "Train Loss", color = 'blue')
plt.plot(history['val_loss'], label = "Val Loss", color = 'orange')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# confusion matrix

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize = (14, 10))
sns.heatmap(cm, annot = True, fmt = 'd', cmap = "Blues", xticklabels = class_names, yticklabels = class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# classification report

# %%
print("Classification Report:\n")
print(classification_report(y_true, y_pred, target_names = class_names))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            A       0.88      1.00      0.94        30
#            B       0.86      1.00      0.92        30
#         BOOK       1.00      1.00      1.00        30
#            C       1.00      0.70      0.82        30
#            D       1.00      1.00      1.00        30
#        DRINK       1.00      1.00      1.00        30
#            E       1.00      1.00      1.00        30
#          EAT       1.00      1.00      1.00        30
#         FOOD       1.00      1.00      1.00        30
#           GO       1.00      1.00      1.00        30
#        HELLO       1.00      1.00      1.00        30
#  HOW ARE YOU       1.00      1.00      1.00        30
#            I       1.00      1.00      1.00        30
#         MAKE       1.00      1.00      1.00        30
#        MONEY       1.00      1.00      1.00        30
#           MY       1.00      1.00      1.00        30
#         READ       1.00      1.00      1.00        30
#       SCHOOL       1.00      1.00      1.00        30
#        WATER       1.00      1.00      1.00        30
#          YOU       1.00      1.00      1.00        30
#
#     accuracy                           0.98       600
#    macro avg       0.99      0.98      0.98       600
# weighted avg       0.99      0.98      0.98       600

# %% [markdown]
# learning rate vs validation accuracy

# %%
if 'learning_rate' in history:
    plt.figure(figsize = (8, 5))
    plt.plot(history['learning_rate'], history['val_sparse_categorical_accuracy'], marker = 'o', linestyle = '-', color = 'purple')
    plt.xlabel("Learning Rate")
    plt.ylabel("Validation Accuracy")
    plt.xscale('log')  # log scale to better visualize LR changes
    plt.title("Learning Rate vs Validation Accuracy")
    plt.grid()
    plt.show()
else:
    print("Learning rate data is not available in history.")
